# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
import os
os.chdir("/content")
os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "expandable_segments:True"

# %%
import subprocess
import shutil

DRIVE_ROOT = "/content/drive/MyDrive/vlm-finetuning-project1"
REPO_DIR = "vlm-safety-reasoning"
ENV_PATH = f"{DRIVE_ROOT}/secrets/.env"

def load_secrets(env_path: str) -> dict:
    if not os.path.exists(env_path):
        raise FileNotFoundError(f"Secrets file not found at: {env_path}")
    secrets = {}
    with open(env_path, "r") as f:
        for line in f:
            line = line.strip()
            if not line or line.startswith("#") or "=" not in line:
                continue
            key, value = line.split("=", 1)
            secrets[key] = value.strip(" \"'\r")
            os.environ[key] = secrets[key]
    return secrets

secrets = load_secrets(ENV_PATH)
required_keys = ["GIT_EMAIL", "GIT_NAME", "GITHUB_USERNAME", "GITHUB_TOKEN", "HF_TOKEN"]
missing = [k for k in required_keys if k not in secrets]
if missing:
    raise KeyError(f"Missing required secrets: {missing}")

subprocess.run(["git", "config", "--global", "user.email", secrets["GIT_EMAIL"]], check=True)
subprocess.run(["git", "config", "--global", "user.name", secrets["GIT_NAME"]], check=True)

AUTH_REPO_URL = (
    f"https://{secrets['GITHUB_USERNAME']}:{secrets['GITHUB_TOKEN']}"
    f"@github.com/epmresearch/vlm-safety-reasoning.git"
)

if os.path.exists(REPO_DIR):
    os.chdir(REPO_DIR)
    subprocess.run(["git", "remote", "set-url", "origin", AUTH_REPO_URL], check=True)
    subprocess.run(["git", "pull", "origin", "main"], check=True)
else:
    subprocess.run(["git", "clone", AUTH_REPO_URL, REPO_DIR], check=True)
    os.chdir(REPO_DIR)

print(f">>> Working directory: {os.getcwd()}")
shutil.copy(ENV_PATH, ".env")
subprocess.run(["pip", "install", "-q", "-r", "requirements.txt"], check=True)
print(">>> Setup complete.")
# Out:
# >>> Working directory: /content/vlm-safety-reasoning
# >>> Setup complete.

# %%
from huggingface_hub import login
import wandb

login(token=os.environ["HF_TOKEN"])
wandb.login(key=os.environ["WANDB_API_KEY"])
# Out:
# Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.
# WARNING:huggingface_hub._login:Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.
# /usr/local/lib/python3.12/dist-packages/notebook/notebookapp.py:191: SyntaxWarning: invalid escape sequence '\/'
#   | |_| | '_ \/ _` / _` |  _/ -_)
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: [wandb.login()] Using explicit session credentials for https://api.wandb.ai.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: nabeel-shan-research (nabeel-shan-research-national-university-of-sciences-and) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# True

# %%
import subprocess, shutil as sh

subprocess.run(["apt-get", "install", "-y", "-q", "openjdk-8-jdk-headless"], check=True)
listing = subprocess.run(["update-alternatives", "--list", "java"], capture_output=True, text=True).stdout
java8_candidates = [line.strip() for line in listing.splitlines() if "java-8" in line]
assert java8_candidates, f"No java-8 found:\n{listing}"
subprocess.run(["update-alternatives", "--set", "java", java8_candidates[0]], check=True)
verify = subprocess.run(["java", "-version"], capture_output=True, text=True).stderr
assert "1.8" in verify, f"Java switch failed: {verify}"
print("Java 8 active.")
# Out:
# Java 8 active.

# %%
# Run the single-pass SFT evaluation (SKIPPING SPICE)
# !python -m experiments.run_evaluation \
    --predictions_path "/content/drive/MyDrive/vlm-finetuning-project1/results/inference/unified-sft-v1_test/repair_applied/predictions_repaired.jsonl" \
    --output_dir "/content/drive/MyDrive/vlm-finetuning-project1/results/inference/unified-sft-v1_test/sft_after_repair_results" \
    --skip_spice
# Out:
# 2026-07-24 14:56:53 | INFO     | __main__:main:123 - Checking Java setup for METEOR/CIDEr-D/SPICE...
# 2026-07-24 14:56:53 | INFO     | __main__:ensure_java8_active:61 - Java 8 already active.
# 2026-07-24 14:56:53 | INFO     | evaluation.spice_cache:restore_spice_cache:59 - Restoring cached CoreNLP models: /content/drive/MyDrive/vlm-finetuning-project1/tools/spice_corenlp_cache -> /usr/local/lib/python3.12/dist-packages/pycocoevalcap/spice/lib
# 2026-07-24 14:56:59 | INFO     | evaluation.spice_cache:restore_spice_cache:72 - SPICE cache restored (2 new item(s) copied).
# 2026-07-24 14:56:59 | INFO     | __main__:main:134 - SPICE/CoreNLP cache restored from Drive: True
# 2026-07-24 14:56:59 | INFO     | core.run_manifest:save_run_manifest:38 - Run manifest saved to /content/drive/MyDrive/vlm-finetuning-project1/results/inference/unified-sft-v1_test/sft_after_repair_results/run_manifest.json
# 2026-07-24 14:56:59 | INFO     | __main__:main:149 - {
#   "experiment": "evaluation_sft_after_repair_results",
#   "predictions_path": "/content/drive/MyDrive/vlm-finetuning-project1/results/inference/unified-sft-v1_test/repair_applied/predictions_repaired.jsonl",
#   "output_dir": "/content/drive/MyDrive/vlm-finetuning-project1/results/inference/unified-sft-v1_test/sft_after_repair_results",
#   "max_samples": null
# }
# 2026-07-24 14:56:59 | INFO     | __main__:main:152 - Loading predictions from /content/drive/MyDrive/vlm-finetuning-project1/results/inference/unified-sft-v1_test/repair_applied/predictions_repaired.jsonl...
# 2026-07-24 14:57:00 | INFO     | __main__:main:156 - Loaded 3004 prediction records.
# 2026-07-24 14:57:00 | INFO     | __main__:main:165 - Loading processed dataset to re-attach images by image_id...
# 2026-07-24 14:57:00 | INFO     | data.loader:load_processed_dataset:183 - Loading fully processed dataset from disk: /content/drive/MyDrive/vlm-finetuning-project1/datasets/processed
# 2026-07-24 14:57:25 | INFO     | data.loader:load_processed_dataset:187 - Loaded processed 'train' split: 6308 samples
# 2026-07-24 14:57:25 | INFO     | data.loader:load_processed_dataset:187 - Loaded processed 'val' split: 701 samples
# 2026-07-24 14:57:25 | INFO     | data.loader:load_processed_dataset:187 - Loaded processed 'test' split: 3004 samples
# 2026-07-24 14:57:56 | INFO     | __main__:main:179 - Running full evaluation pipeline...
# 2026-07-24 14:57:56 | INFO     | evaluation.evaluator:run_full_evaluation:36 - Starting full evaluation pipeline...
# 2026-07-24 14:57:56 | INFO     | evaluation.evaluator:run_full_evaluation:101 - Computing captioning metrics...
# config.json: 100% 482/482 [00:00<00:00, 2.13MB/s]
# tokenizer_config.json: 100% 25.0/25.0 [00:00<00:00, 115kB/s]
# vocab.json: 100% 899k/899k [00:00<00:00, 22.6MB/s]
# merges.txt: 100% 456k/456k [00:00<00:00, 27.3MB/s]
# tokenizer.json: 100% 1.36M/1.36M [00:00<00:00, 43.9MB/s]
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so
#
# model.safetensors: downloading bytes:  12% 166M/1.42G [00:00<00:05, 251MB/s, 12.8MB/s  ]
# model.safetensors: reconstructing file:   5% 67.0M/1.42G [00:01<00:21, 62.2MB/s]
# model.safetensors: downloading bytes:  33% 465M/1.42G [00:01<00:02, 371MB/s, 39.4MB/s  ]
# model.safetensors: downloading bytes:  66% 943M/1.42G [00:02<00:01, 386MB/s, 80.8MB/s  ]
# model.safetensors: reconstructing file:  66% 938M/1.42G [00:03<00:01, 327MB/s, 30.8MB/s  ]
# model.safetensors: downloading bytes: 100% 952M/952M [00:03<00:00, 240MB/s, 80.8MB/s  ]
# model.safetensors: reconstructing file: 100% 1.42G/1.42G [00:03<00:00, 358MB/s,  122MB/s  ]
# Loading weights: 100% 389/389 [00:00<00:00, 3091.94it/s]
# PTBTokenizer tokenized 164806 tokens at 798939.55 tokens per second.
# PTBTokenizer tokenized 92058 tokens at 588280.79 tokens per second.
# PTBTokenizer tokenized 164806 tokens at 759351.08 tokens per second.
# PTBTokenizer tokenized 92058 tokens at 618499.34 tokens per second.
# 2026-07-24 14:59:12 | INFO     | evaluation.metrics_captioning:compute_clipscore:268 - Computing CLIPScore (batched)...
# preprocessor_config.json: 100% 316/316 [00:00<00:00, 1.57MB/s]
# config.json: 100% 4.19k/4.19k [00:00<00:00, 4.63MB/s]
# tokenizer_config.json: 100% 592/592 [00:00<00:00, 2.88MB/s]
# vocab.json: 100% 862k/862k [00:00<00:00, 20.7MB/s]
# merges.txt: 100% 525k/525k [00:00<00:00, 94.9MB/s]
# tokenizer.json: 100% 2.22M/2.22M [00:00<00:00, 129MB/s]
# special_tokens_map.json: 100% 389/389 [00:00<00:00, 2.44MB/s]
#
# pytorch_model.bin: downloading bytes:  20% 123M/605M [00:00<00:02, 229MB/s, 8.07MB/s  ]
# pytorch_model.bin: downloading bytes:  27% 165M/605M [00:00<00:01, 280MB/s, 12.0MB/s  ]
# pytorch_model.bin: downloading bytes:  36% 221M/605M [00:01<00:01, 279MB/s, 18.8MB/s  ]
# pytorch_model.bin: downloading bytes:  42% 255M/605M [00:01<00:01, 294MB/s, 21.1MB/s  ]
# pytorch_model.bin: downloading bytes:  54% 329M/605M [00:01<00:01, 262MB/s, 29.1MB/s  ]
# pytorch_model.bin: downloading bytes:  70% 426M/605M [00:02<00:00, 187MB/s, 37.3MB/s  ]
# pytorch_model.bin: downloading bytes: 100% 433M/433M [00:02<00:00, 193MB/s, 38.1MB/s  ]
# pytorch_model.bin: reconstructing file: 100% 605M/605M [00:02<00:00, 271MB/s, 54.0MB/s  ]
# Loading weights: 100% 398/398 [00:00<00:00, 14674.16it/s]
#
# model.safetensors: downloading bytes:  39% 239M/605M [00:00<00:00, 370MB/s, 19.1MB/s  ]
# model.safetensors: downloading bytes:  71% 432M/605M [00:01<00:00, 316MB/s, 39.0MB/s  ]
# model.safetensors: reconstructing file:  33% 201M/605M [00:01<00:02, 150MB/s,  819kB/s  ]
# model.safetensors: downloading bytes: 100% 432M/432M [00:02<00:00, 205MB/s, 39.6MB/s  ]
# model.safetensors: reconstructing file: 100% 605M/605M [00:02<00:00, 287MB/s, 56.9MB/s  ]
# 2026-07-24 14:59:55 | INFO     | evaluation.evaluator:run_full_evaluation:113 - Computing grounding metrics...
# 2026-07-24 14:59:56 | INFO     | evaluation.evaluator:run_full_evaluation:117 - Computing safety violation metrics...
# 2026-07-24 14:59:56 | INFO     | evaluation.evaluator:run_full_evaluation:121 - Computing reasoning metrics (Captioning Suite)...
# Reasoning Eval: 100% 3004/3004 [00:00<00:00, 430243.78it/s]
# 2026-07-24 14:59:56 | INFO     | evaluation.metrics_reasoning:batch_score_reasoning:80 - Computing global reasoning metrics over 137 valid reasons...
# Loading weights: 100% 389/389 [00:00<00:00, 4015.83it/s]
# PTBTokenizer tokenized 2179 tokens at 39502.18 tokens per second.
# PTBTokenizer tokenized 1668 tokens at 34781.68 tokens per second.
# PTBTokenizer tokenized 2179 tokens at 45127.39 tokens per second.
# PTBTokenizer tokenized 1668 tokens at 35633.88 tokens per second.
# 2026-07-24 15:00:06 | INFO     | evaluation.metrics_captioning:compute_clipscore:268 - Computing CLIPScore (batched)...
# 2026-07-24 15:00:08 | INFO     | evaluation.metrics_reasoning:batch_score_reasoning:99 - Computing reasoning metrics for rule_1 over 128 valid reasons...
# Loading weights: 100% 389/389 [00:00<00:00, 4270.98it/s]
# PTBTokenizer tokenized 2039 tokens at 39223.39 tokens per second.
# PTBTokenizer tokenized 1555 tokens at 32728.69 tokens per second.
# PTBTokenizer tokenized 2039 tokens at 40533.80 tokens per second.
# PTBTokenizer tokenized 1555 tokens at 33187.63 tokens per second.
# 2026-07-24 15:00:18 | INFO     | evaluation.metrics_captioning:compute_clipscore:268 - Computing CLIPScore (batched)...
# 2026-07-24 15:00:20 | INFO     | evaluation.metrics_reasoning:batch_score_reasoning:99 - Computing reasoning metrics for rule_2 over 7 valid reasons...
# Loading weights: 100% 389/389 [00:00<00:00, 4228.84it/s]
# PTBTokenizer tokenized 112 tokens at 2660.86 tokens per second.
# PTBTokenizer tokenized 90 tokens at 2253.17 tokens per second.
# PTBTokenizer tokenized 112 tokens at 2863.27 tokens per second.
# PTBTokenizer tokenized 90 tokens at 2318.57 tokens per second.
# 2026-07-24 15:00:30 | INFO     | evaluation.metrics_captioning:compute_clipscore:268 - Computing CLIPScore (batched)...
# 2026-07-24 15:00:30 | INFO     | evaluation.metrics_reasoning:batch_score_reasoning:99 - Computing reasoning metrics for rule_3 over 2 valid reasons...
# Loading weights: 100% 389/389 [00:00<00:00, 4387.41it/s]
# PTBTokenizer tokenized 26 tokens at 604.59 tokens per second.
# PTBTokenizer tokenized 21 tokens at 534.72 tokens per second.
# PTBTokenizer tokenized 26 tokens at 547.00 tokens per second.
# PTBTokenizer tokenized 21 tokens at 459.45 tokens per second.
# 2026-07-24 15:00:39 | INFO     | evaluation.metrics_captioning:compute_clipscore:268 - Computing CLIPScore (batched)...
# 2026-07-24 15:00:39 | INFO     | evaluation.evaluator:run_full_evaluation:132 - Evaluation complete. 0 schema failures logged.
# 2026-07-24 15:00:39 | INFO     | __main__:main:201 - Metrics saved to: /content/drive/MyDrive/vlm-finetuning-project1/results/inference/unified-sft-v1_test/sft_after_repair_results/metrics.json
# 2026-07-24 15:00:39 | INFO     | __main__:main:230 - JSON Parse failures logged to: /content/drive/MyDrive/vlm-finetuning-project1/results/inference/unified-sft-v1_test/sft_after_repair_results/json_parse_failures.json (0 failures)
# 2026-07-24 15:00:39 | INFO     | __main__:main:231 - Schema Validation failures logged to: /content/drive/MyDrive/vlm-finetuning-project1/results/inference/unified-sft-v1_test/sft_after_repair_results/schema_validation_failures.json (0 failures)
# 2026-07-24 15:00:39 | INFO     | __main__:main:244 - Parsed predictions saved to: /content/drive/MyDrive/vlm-finetuning-project1/results/inference/unified-sft-v1_test/sft_after_repair_results/parsed_predictions.json
# 2026-07-24 15:00:39 | INFO     | __main__:main:259 - Combined predictions+eval saved to: /content/drive/MyDrive/vlm-finetuning-project1/results/inference/unified-sft-v1_test/sft_after_repair_results/predictions_with_eval.json
# 2026-07-24 15:00:39 | INFO     | __main__:main:288 - Evaluation complete. All artifacts saved to: /content/drive/MyDrive/vlm-finetuning-project1/results/inference/unified-sft-v1_test/sft_after_repair_results
# 2026-07-24 15:00:39 | INFO     | __main__:main:289 - Total metrics tracked: 154

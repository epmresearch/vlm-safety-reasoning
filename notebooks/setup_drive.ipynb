# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# !ls
# Out:
# drive  sample_data

# %%
# !git clone https://github.com/your-username/vlm-safety-reasoning.git /content/vlm-safety-reasoning
# %cd /content/vlm-safety-reasoning

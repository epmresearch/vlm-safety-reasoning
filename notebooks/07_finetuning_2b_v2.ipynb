# %%
import os
import subprocess
import shutil

os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "expandable_segments:True"

DRIVE_ROOT = "/content/drive/MyDrive/vlm-finetuning-project1"
REPO_DIR = "vlm-safety-reasoning"
ENV_PATH = f"{DRIVE_ROOT}/secrets/.env"

def load_secrets(env_path: str) -> dict:
    if not os.path.exists(env_path):
        raise FileNotFoundError(f"Secrets file not found at: {env_path}")
    secrets = {}
    with open(env_path, "r") as f:
        for line in f:
            line = line.strip()
            if not line or line.startswith("#") or "=" not in line:
                continue
            key, value = line.split("=", 1)
            secrets[key] = value.strip(" \"'\r")
            os.environ[key] = secrets[key]
    return secrets

print(">>> Loading secrets...")
secrets = load_secrets(ENV_PATH)

print(">>> Configuring Git identity...")
subprocess.run(["git", "config", "--global", "user.email", secrets["GIT_EMAIL"]], check=True)
subprocess.run(["git", "config", "--global", "user.name", secrets["GIT_NAME"]], check=True)

AUTH_REPO_URL = f"https://{secrets['GITHUB_USERNAME']}:{secrets['GITHUB_TOKEN']}@github.com/epmresearch/vlm-safety-reasoning.git"

if os.path.exists(REPO_DIR):
    os.chdir(REPO_DIR)
    subprocess.run(["git", "remote", "set-url", "origin", AUTH_REPO_URL], check=True)
    subprocess.run(["git", "pull", "origin", "main"], check=True)
else:
    subprocess.run(["git", "clone", AUTH_REPO_URL, REPO_DIR], check=True)
    os.chdir(REPO_DIR)

shutil.copy(ENV_PATH, ".env")
subprocess.run(["pip", "install", "-q", "-r", "requirements.txt"], check=True)
print(">>> Setup complete. CWD:", os.getcwd())
# Out:
# >>> Loading secrets...
# >>> Configuring Git identity...
# >>> Setup complete. CWD: /content/vlm-safety-reasoning

# %%
from huggingface_hub import login
import wandb

login(token=os.environ["HF_TOKEN"])
wandb.login(key=os.environ["WANDB_API_KEY"])
# Out:
# Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.
# WARNING:huggingface_hub._login:Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.
# /usr/local/lib/python3.12/dist-packages/notebook/notebookapp.py:191: SyntaxWarning: invalid escape sequence '\/'
#   | |_| | '_ \/ _` / _` |  _/ -_)
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: [wandb.login()] Using explicit session credentials for https://api.wandb.ai.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: nabeel-shan-research (nabeel-shan-research-national-university-of-sciences-and) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# True

# %%
# !python -m experiments.run_sft --tier 2b --variant unified-sft-v1
# !python -m experiments.run_sft --tier 2b --variant unified-sft64-v2-visionlora
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# 2026-07-21 08:25:40 | INFO     | __main__:main:38 - Loading fully processed and sorted dataset splits...
# 2026-07-21 08:25:40 | INFO     | data.loader:load_processed_dataset:183 - Loading fully processed dataset from disk: /content/drive/MyDrive/vlm-finetuning-project1/datasets/processed
# 2026-07-21 08:26:11 | INFO     | data.loader:load_processed_dataset:187 - Loaded processed 'train' split: 6308 samples
# 2026-07-21 08:26:11 | INFO     | data.loader:load_processed_dataset:187 - Loaded processed 'val' split: 701 samples
# 2026-07-21 08:26:11 | INFO     | data.loader:load_processed_dataset:187 - Loaded processed 'test' split: 3004 samples
# 2026-07-21 08:26:11 | INFO     | __main__:main:47 - Building oversampled dataset...
# 2026-07-21 08:27:04 | INFO     | data.oversampling:build_oversampled_indices:70 - Oversampling: 6308 -> 6690 rows (+382). Rule2/4 images=95 (x4), Rule3-only images=97 (x2)
# 2026-07-21 08:27:07 | INFO     | __main__:main:59 - Saved oversample manifest to /content/drive/MyDrive/vlm-finetuning-project1/datasets/stats/oversample_manifest_2b_unified-sft64-v2-visionlora.json
# 2026-07-21 08:27:07 | INFO     | __main__:main:63 - Building rare mask for stratified sampling...
# 2026-07-21 08:27:56 | INFO     | __main__:main:72 - Preprocessing datasets for unified SFT...
# 2026-07-21 08:28:59 | INFO     | data.preprocessor:build_unified_sft_dataset:121 - Built unified SFT dataset: 6690 samples (0 skipped)
# 2026-07-21 08:29:06 | INFO     | data.preprocessor:build_unified_sft_dataset:121 - Built unified SFT dataset: 701 samples (0 skipped)
# 2026-07-21 08:29:06 | INFO     | __main__:main:83 - Starting SFT for tier: 2b, variant: unified-sft64-v2-visionlora...
# 2026-07-21 08:29:06 | INFO     | models.model_loader:load_model_for_training:109 - Loading model: unsloth/Qwen3-VL-2B-Instruct (4-bit=True)
# ==((====))==  Unsloth 2026.7.4: Fast Qwen3_Vl patching. Transformers: 5.5.0.
#    \\   /|    NVIDIA A100-SXM4-40GB. Num GPUs = 1. Max memory: 39.494 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.11.0+cu128. CUDA: 8.0. CUDA Toolkit: 12.8. Triton: 3.6.0
# \        /    Bfloat16 = TRUE. FA [Xformers = None. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# Loading weights: 100% 625/625 [00:00<00:00, 800.11it/s]
# 2026-07-21 08:29:49 | INFO     | models.model_loader:load_model_for_training:117 - Applying LoRA: r=64, alpha=64, dropout=0.05, vision_frozen=False
# Unsloth: Dropout = 0 is supported for fast patching. You are using dropout = 0.05.
# Unsloth will patch all other layers, except LoRA matrices, causing a performance hit.
# 2026-07-21 08:29:54 | INFO     | models.model_loader:apply_pixel_bounds:235 - Applied image pixel bounds via size dict: min=200704, max=1204224
# 2026-07-21 08:29:55 | INFO     | models.model_loader:log_gpu_memory:248 - [GPU MEM after model load] allocated=2.80GB reserved=2.80GB total=42.41GB free~=39.60GB
# warmup_ratio is deprecated and will be removed in v5.2. Use `warmup_steps` instead.
# Unsloth: Model does not have a default image size - using 512
# wandb: [wandb.login()] Using explicit session credentials for https://api.wandb.ai.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: nabeel-shan-research (nabeel-shan-research-national-university-of-sciences-and) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Using an existing wandb-core service via WANDB_SERVICE.
# wandb: WARNING Using a boolean value for 'reinit' is deprecated. Use 'return_previous' or 'finish_previous' instead.
# wandb: ⢿ Waiting for wandb.init()...
# wandb: ⣻ Waiting for wandb.init()...
# wandb: ⣽ Waiting for wandb.init()...
# wandb: ⣾ Waiting for wandb.init()...
# wandb: ⣷ setting up run ajsjbuoq (0.5s)
# wandb: Tracking run with wandb version 0.28.0
# wandb: Run data is saved locally in /content/vlm-safety-reasoning/wandb/run-20260721_082955-ajsjbuoq
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run qwen3vl-2b-unified-sft64-v2-visionlora
# wandb: ⭐️ View project at https://wandb.ai/nabeel-shan-research-national-university-of-sciences-and/vlm-safety-project1
# wandb: 🚀 View run at https://wandb.ai/nabeel-shan-research-national-university-of-sciences-and/vlm-safety-project1/runs/ajsjbuoq
# wandb: Detected [huggingface_hub.inference, openai] in use.
# wandb: Use W&B Weave for improved LLM call tracing. Install Weave with `pip install weave` then add `import weave` to the top of your script.
# wandb: For more information, check out the docs at: https://weave-docs.wandb.ai
# 2026-07-21 08:29:57 | INFO     | models.sft_trainer:run_sft_unified:313 - Stratified rare-class sampling ENABLED for train dataloader.
# 2026-07-21 08:29:57 | INFO     | models.sft_trainer:run_sft_unified:332 - Starting SFT: model=unsloth/Qwen3-VL-2B-Instruct, variant=unified-sft64-v2-visionlora, n_train=6690, n_val=701, effective_batch=32
# 2026-07-21 08:29:57 | INFO     | models.model_loader:log_gpu_memory:248 - [GPU MEM before trainer.train()] allocated=2.80GB reserved=2.80GB total=42.41GB free~=39.60GB
# The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'bos_token_id': None}.
# 2026-07-21 08:29:58 | INFO     | data.samplers:__init__:115 - StratifiedRareClassSampler: 6690 samples -> 574 rare, 6116 common
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs used = 1
#    \\   /|    Num examples = 6,690 | Num Epochs = 2 | Total steps = 418
# O^O/ \_/ \    Batch size per device = 32 | Gradient accumulation steps = 1
# \        /    Data Parallel GPUs = 1 | Total batch size (32 x 1 x 1) = 32
#  "-____-"     Trainable parameters = 94,896,128 of 2,222,428,160 (4.27% trained)
#   0% 0/418 [00:00<?, ?it/s]Unsloth: Will smartly offload gradients to save VRAM!
# {'loss': '1.19', 'grad_norm': '3.006', 'learning_rate': '0', 'epoch': '0.004785'}
#   0% 1/418 [01:03<7:23:35, 63.83s/it]Unsloth: Double buffering enabled (parallel H2D + compute) for backward pass.
# {'loss': '1.222', 'grad_norm': '2.946', 'learning_rate': '7.143e-07', 'epoch': '0.009569'}
# {'loss': '1.2', 'grad_norm': '2.911', 'learning_rate': '1.429e-06', 'epoch': '0.01435'}
# {'loss': '1.249', 'grad_norm': '3.163', 'learning_rate': '2.143e-06', 'epoch': '0.01914'}
# {'loss': '1.244', 'grad_norm': '3.148', 'learning_rate': '2.857e-06', 'epoch': '0.02392'}
# {'loss': '1.222', 'grad_norm': '3.01', 'learning_rate': '3.571e-06', 'epoch': '0.02871'}
# {'loss': '1.202', 'grad_norm': '2.806', 'learning_rate': '4.286e-06', 'epoch': '0.03349'}
# {'loss': '1.203', 'grad_norm': '3.015', 'learning_rate': '5e-06', 'epoch': '0.03828'}
# {'loss': '1.172', 'grad_norm': '2.952', 'learning_rate': '5.714e-06', 'epoch': '0.04306'}
# {'loss': '1.168', 'grad_norm': '2.91', 'learning_rate': '6.429e-06', 'epoch': '0.04785'}
# {'loss': '1.191', 'grad_norm': '2.786', 'learning_rate': '7.143e-06', 'epoch': '0.05263'}
# {'loss': '1.095', 'grad_norm': '2.531', 'learning_rate': '7.857e-06', 'epoch': '0.05742'}
# {'loss': '1.127', 'grad_norm': '2.628', 'learning_rate': '8.571e-06', 'epoch': '0.0622'}
# {'loss': '1.079', 'grad_norm': '2.098', 'learning_rate': '9.286e-06', 'epoch': '0.06699'}
# {'loss': '1.062', 'grad_norm': '1.833', 'learning_rate': '1e-05', 'epoch': '0.07177'}
# {'loss': '1.061', 'grad_norm': '1.584', 'learning_rate': '1.071e-05', 'epoch': '0.07656'}
# {'loss': '1.029', 'grad_norm': '1.546', 'learning_rate': '1.143e-05', 'epoch': '0.08134'}
# {'loss': '0.9759', 'grad_norm': '1.211', 'learning_rate': '1.214e-05', 'epoch': '0.08612'}
# {'loss': '1.016', 'grad_norm': '1.158', 'learning_rate': '1.286e-05', 'epoch': '0.09091'}
# {'loss': '0.9496', 'grad_norm': '0.9267', 'learning_rate': '1.357e-05', 'epoch': '0.09569'}
# {'loss': '0.936', 'grad_norm': '0.7803', 'learning_rate': '1.429e-05', 'epoch': '0.1005'}
# {'loss': '0.9147', 'grad_norm': '0.7292', 'learning_rate': '1.5e-05', 'epoch': '0.1053'}
# {'loss': '0.8494', 'grad_norm': '0.5936', 'learning_rate': '1.571e-05', 'epoch': '0.11'}
# {'loss': '0.8916', 'grad_norm': '0.5915', 'learning_rate': '1.643e-05', 'epoch': '0.1148'}
# {'loss': '0.8531', 'grad_norm': '0.6613', 'learning_rate': '1.714e-05', 'epoch': '0.1196'}
# {'loss': '0.8494', 'grad_norm': '0.6037', 'learning_rate': '1.786e-05', 'epoch': '0.1244'}
# {'loss': '0.8437', 'grad_norm': '0.7074', 'learning_rate': '1.857e-05', 'epoch': '0.1292'}
# {'loss': '0.8694', 'grad_norm': '0.6312', 'learning_rate': '1.929e-05', 'epoch': '0.134'}
# {'loss': '0.8065', 'grad_norm': '0.6184', 'learning_rate': '2e-05', 'epoch': '0.1388'}
# {'loss': '0.8282', 'grad_norm': '0.5965', 'learning_rate': '2.071e-05', 'epoch': '0.1435'}
# {'loss': '0.8149', 'grad_norm': '0.5644', 'learning_rate': '2.143e-05', 'epoch': '0.1483'}
# {'loss': '0.7742', 'grad_norm': '0.5506', 'learning_rate': '2.214e-05', 'epoch': '0.1531'}
# {'loss': '0.8381', 'grad_norm': '0.527', 'learning_rate': '2.286e-05', 'epoch': '0.1579'}
# {'loss': '0.7828', 'grad_norm': '0.4818', 'learning_rate': '2.357e-05', 'epoch': '0.1627'}
# {'loss': '0.764', 'grad_norm': '0.434', 'learning_rate': '2.429e-05', 'epoch': '0.1675'}
# {'loss': '0.7798', 'grad_norm': '0.3756', 'learning_rate': '2.5e-05', 'epoch': '0.1722'}
# {'loss': '0.7994', 'grad_norm': '0.3667', 'learning_rate': '2.571e-05', 'epoch': '0.177'}
# {'loss': '0.7421', 'grad_norm': '0.3428', 'learning_rate': '2.643e-05', 'epoch': '0.1818'}
# {'loss': '0.7262', 'grad_norm': '0.3216', 'learning_rate': '2.714e-05', 'epoch': '0.1866'}
# {'loss': '0.7871', 'grad_norm': '0.3435', 'learning_rate': '2.786e-05', 'epoch': '0.1914'}
# {'loss': '0.7473', 'grad_norm': '0.3332', 'learning_rate': '2.857e-05', 'epoch': '0.1962'}
# {'loss': '0.7292', 'grad_norm': '0.3354', 'learning_rate': '2.929e-05', 'epoch': '0.201'}
# {'loss': '0.7328', 'grad_norm': '0.343', 'learning_rate': '3e-05', 'epoch': '0.2057'}
# {'loss': '0.6719', 'grad_norm': '0.3773', 'learning_rate': '3e-05', 'epoch': '0.2105'}
# {'loss': '0.7191', 'grad_norm': '0.3542', 'learning_rate': '3e-05', 'epoch': '0.2153'}
# {'loss': '0.7174', 'grad_norm': '0.332', 'learning_rate': '3e-05', 'epoch': '0.2201'}
# {'loss': '0.681', 'grad_norm': '0.3319', 'learning_rate': '2.999e-05', 'epoch': '0.2249'}
# {'loss': '0.6969', 'grad_norm': '0.3117', 'learning_rate': '2.999e-05', 'epoch': '0.2297'}
# {'loss': '0.684', 'grad_norm': '0.344', 'learning_rate': '2.998e-05', 'epoch': '0.2344'}
# {'loss': '0.6379', 'grad_norm': '0.3033', 'learning_rate': '2.997e-05', 'epoch': '0.2392'}
#  12% 50/418 [04:48<26:33,  4.33s/it]
#   0% 0/21 [00:00<?, ?it/s]
#  10% 2/21 [00:02<00:19,  1.03s/it]
#  14% 3/21 [00:04<00:28,  1.59s/it]
#  19% 4/21 [00:06<00:32,  1.91s/it]
#  24% 5/21 [00:09<00:33,  2.09s/it]
#  29% 6/21 [00:11<00:32,  2.18s/it]
#  33% 7/21 [00:14<00:32,  2.33s/it]
#  38% 8/21 [00:17<00:32,  2.48s/it]
#  43% 9/21 [00:19<00:30,  2.58s/it]
#  48% 10/21 [00:22<00:29,  2.64s/it]
#  52% 11/21 [00:25<00:26,  2.67s/it]
#  57% 12/21 [00:28<00:24,  2.69s/it]
#  62% 13/21 [00:30<00:21,  2.72s/it]
#  67% 14/21 [00:33<00:19,  2.73s/it]
#  71% 15/21 [00:36<00:16,  2.73s/it]
#  76% 16/21 [00:39<00:13,  2.74s/it]
#  81% 17/21 [00:42<00:11,  2.76s/it]
#  86% 18/21 [00:44<00:08,  2.77s/it]
#  90% 19/21 [00:47<00:05,  2.76s/it]
#  95% 20/21 [00:49<00:02,  2.66s/it]
#
# {'eval_loss': '0.6956', 'eval_runtime': '64.79', 'eval_samples_per_second': '10.82', 'eval_steps_per_second': '0.34', 'epoch': '0.2392'}
#  12% 50/418 [05:53<26:33,  4.33s/it]
# 100% 21/21 [00:51<00:00,  2.20s/it]2026-07-21 08:35:52 | INFO     | core.callbacks:on_evaluate:58 - New best eval_loss=0.6956 at step 50 -> saving to /content/drive/MyDrive/vlm-finetuning-project1/checkpoints/qwen3vl-2b/unified-sft64-v2-visionlora/best
# Unsloth: Restored added_tokens_decoder metadata in /content/drive/MyDrive/vlm-finetuning-project1/checkpoints/qwen3vl-2b/unified-sft64-v2-visionlora/best/tokenizer_config.json.
#
#                                    Unsloth: Restored added_tokens_decoder metadata in /content/drive/MyDrive/vlm-finetuning-project1/checkpoints/qwen3vl-2b/unified-sft64-v2-visionlora/checkpoint-50/tokenizer_config.json.
# {'loss': '0.7295', 'grad_norm': '0.314', 'learning_rate': '2.997e-05', 'epoch': '0.244'}
# {'loss': '0.7002', 'grad_norm': '0.3519', 'learning_rate': '2.996e-05', 'epoch': '0.2488'}
# {'loss': '0.6893', 'grad_norm': '0.3286', 'learning_rate': '2.995e-05', 'epoch': '0.2536'}
# {'loss': '0.6318', 'grad_norm': '0.3154', 'learning_rate': '2.994e-05', 'epoch': '0.2584'}
# {'loss': '0.7113', 'grad_norm': '0.3584', 'learning_rate': '2.992e-05', 'epoch': '0.2632'}
# {'loss': '0.6723', 'grad_norm': '0.3307', 'learning_rate': '2.991e-05', 'epoch': '0.2679'}
# {'loss': '0.6938', 'grad_norm': '0.2991', 'learning_rate': '2.99e-05', 'epoch': '0.2727'}
# {'loss': '0.6752', 'grad_norm': '0.3073', 'learning_rate': '2.988e-05', 'epoch': '0.2775'}
# {'loss': '0.6313', 'grad_norm': '0.3416', 'learning_rate': '2.987e-05', 'epoch': '0.2823'}
#  14% 60/418 [06:44<30:17,  5.08s/it]wandb: WARNING Tried to log to step 60 that is less than the current step 61. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# {'loss': '0.6612', 'grad_norm': '0.2965', 'learning_rate': '2.985e-05', 'epoch': '0.2871'}
# {'loss': '0.6314', 'grad_norm': '0.3084', 'learning_rate': '2.983e-05', 'epoch': '0.2919'}
# {'loss': '0.7018', 'grad_norm': '0.2873', 'learning_rate': '2.981e-05', 'epoch': '0.2967'}
# {'loss': '0.632', 'grad_norm': '0.3323', 'learning_rate': '2.979e-05', 'epoch': '0.3014'}
# {'loss': '0.6374', 'grad_norm': '0.2759', 'learning_rate': '2.977e-05', 'epoch': '0.3062'}
# {'loss': '0.6736', 'grad_norm': '0.2834', 'learning_rate': '2.975e-05', 'epoch': '0.311'}
# {'loss': '0.6392', 'grad_norm': '0.3086', 'learning_rate': '2.972e-05', 'epoch': '0.3158'}
# {'loss': '0.6938', 'grad_norm': '0.2924', 'learning_rate': '2.97e-05', 'epoch': '0.3206'}
# {'loss': '0.6111', 'grad_norm': '0.3078', 'learning_rate': '2.967e-05', 'epoch': '0.3254'}
# {'loss': '0.6473', 'grad_norm': '0.3203', 'learning_rate': '2.965e-05', 'epoch': '0.3301'}
# {'loss': '0.6191', 'grad_norm': '0.2944', 'learning_rate': '2.962e-05', 'epoch': '0.3349'}
# {'loss': '0.6689', 'grad_norm': '0.3123', 'learning_rate': '2.959e-05', 'epoch': '0.3397'}
# {'loss': '0.5622', 'grad_norm': '0.2919', 'learning_rate': '2.956e-05', 'epoch': '0.3445'}
# {'loss': '0.64', 'grad_norm': '0.3069', 'learning_rate': '2.953e-05', 'epoch': '0.3493'}
# {'loss': '0.6579', 'grad_norm': '0.3091', 'learning_rate': '2.95e-05', 'epoch': '0.3541'}
# {'loss': '0.6412', 'grad_norm': '0.285', 'learning_rate': '2.947e-05', 'epoch': '0.3589'}
# {'loss': '0.6413', 'grad_norm': '0.3152', 'learning_rate': '2.943e-05', 'epoch': '0.3636'}
# {'loss': '0.6551', 'grad_norm': '0.2771', 'learning_rate': '2.94e-05', 'epoch': '0.3684'}
# {'loss': '0.6674', 'grad_norm': '0.3028', 'learning_rate': '2.936e-05', 'epoch': '0.3732'}
# {'loss': '0.6769', 'grad_norm': '0.3165', 'learning_rate': '2.933e-05', 'epoch': '0.378'}
#  19% 80/418 [08:12<25:01,  4.44s/it]wandb: WARNING Tried to log to step 80 that is less than the current step 81. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# {'loss': '0.7073', 'grad_norm': '0.3131', 'learning_rate': '2.929e-05', 'epoch': '0.3828'}
# {'loss': '0.6393', 'grad_norm': '0.3085', 'learning_rate': '2.925e-05', 'epoch': '0.3876'}
# {'loss': '0.6005', 'grad_norm': '0.3058', 'learning_rate': '2.921e-05', 'epoch': '0.3923'}
# {'loss': '0.5699', 'grad_norm': '0.3389', 'learning_rate': '2.917e-05', 'epoch': '0.3971'}
# {'loss': '0.6348', 'grad_norm': '0.3302', 'learning_rate': '2.913e-05', 'epoch': '0.4019'}
# {'loss': '0.5793', 'grad_norm': '0.2876', 'learning_rate': '2.909e-05', 'epoch': '0.4067'}
# {'loss': '0.6365', 'grad_norm': '0.3286', 'learning_rate': '2.904e-05', 'epoch': '0.4115'}
# {'loss': '0.6235', 'grad_norm': '0.3609', 'learning_rate': '2.9e-05', 'epoch': '0.4163'}
# {'loss': '0.5631', 'grad_norm': '0.3051', 'learning_rate': '2.895e-05', 'epoch': '0.4211'}
# {'loss': '0.7009', 'grad_norm': '0.3695', 'learning_rate': '2.891e-05', 'epoch': '0.4258'}
# {'loss': '0.6307', 'grad_norm': '0.3225', 'learning_rate': '2.886e-05', 'epoch': '0.4306'}
# {'loss': '0.617', 'grad_norm': '0.2982', 'learning_rate': '2.881e-05', 'epoch': '0.4354'}
# {'loss': '0.6327', 'grad_norm': '0.3065', 'learning_rate': '2.876e-05', 'epoch': '0.4402'}
# {'loss': '0.5906', 'grad_norm': '0.3207', 'learning_rate': '2.871e-05', 'epoch': '0.445'}
# {'loss': '0.6568', 'grad_norm': '0.3194', 'learning_rate': '2.866e-05', 'epoch': '0.4498'}
# {'loss': '0.584', 'grad_norm': '0.3515', 'learning_rate': '2.861e-05', 'epoch': '0.4545'}
# {'loss': '0.6498', 'grad_norm': '0.3311', 'learning_rate': '2.855e-05', 'epoch': '0.4593'}
# {'loss': '0.6801', 'grad_norm': '0.3141', 'learning_rate': '2.85e-05', 'epoch': '0.4641'}
# {'loss': '0.6274', 'grad_norm': '0.3445', 'learning_rate': '2.844e-05', 'epoch': '0.4689'}
# {'loss': '0.6132', 'grad_norm': '0.3376', 'learning_rate': '2.839e-05', 'epoch': '0.4737'}
#  24% 100/418 [09:39<23:26,  4.42s/it]wandb: WARNING Tried to log to step 100 that is less than the current step 101. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# {'loss': '0.6716', 'grad_norm': '0.326', 'learning_rate': '2.833e-05', 'epoch': '0.4785'}
#  24% 100/418 [09:39<23:26,  4.42s/it]
#   0% 0/21 [00:00<?, ?it/s]
#  10% 2/21 [00:02<00:24,  1.29s/it]
#  14% 3/21 [00:04<00:29,  1.64s/it]
#  19% 4/21 [00:07<00:32,  1.94s/it]
#  24% 5/21 [00:09<00:35,  2.21s/it]
#  29% 6/21 [00:12<00:33,  2.26s/it]
#  33% 7/21 [00:14<00:33,  2.41s/it]
#  38% 8/21 [00:17<00:32,  2.53s/it]
#  43% 9/21 [00:20<00:32,  2.72s/it]
#  48% 10/21 [00:23<00:31,  2.83s/it]
#  52% 11/21 [00:26<00:27,  2.72s/it]
#  57% 12/21 [00:29<00:25,  2.79s/it]
#  62% 13/21 [00:31<00:21,  2.72s/it]
#  67% 14/21 [00:34<00:19,  2.81s/it]
#  71% 15/21 [00:37<00:16,  2.79s/it]
#  76% 16/21 [00:40<00:13,  2.79s/it]
#  81% 17/21 [00:43<00:11,  2.81s/it]
#  86% 18/21 [00:46<00:08,  2.81s/it]
#  90% 19/21 [00:48<00:05,  2.79s/it]
#  95% 20/21 [00:51<00:02,  2.70s/it]
#
# {'eval_loss': '0.6224', 'eval_runtime': '55.21', 'eval_samples_per_second': '12.7', 'eval_steps_per_second': '0.398', 'epoch': '0.4785'}
#  24% 100/418 [10:34<23:26,  4.42s/it]
# 100% 21/21 [00:52<00:00,  2.22s/it]2026-07-21 08:40:34 | INFO     | core.callbacks:on_evaluate:58 - New best eval_loss=0.6224 at step 100 -> saving to /content/drive/MyDrive/vlm-finetuning-project1/checkpoints/qwen3vl-2b/unified-sft64-v2-visionlora/best
#
#                                    Unsloth: Restored added_tokens_decoder metadata in /content/drive/MyDrive/vlm-finetuning-project1/checkpoints/qwen3vl-2b/unified-sft64-v2-visionlora/checkpoint-100/tokenizer_config.json.
# {'loss': '0.6174', 'grad_norm': '0.3177', 'learning_rate': '2.827e-05', 'epoch': '0.4833'}
# {'loss': '0.6161', 'grad_norm': '0.3107', 'learning_rate': '2.821e-05', 'epoch': '0.488'}
# {'loss': '0.5955', 'grad_norm': '0.325', 'learning_rate': '2.815e-05', 'epoch': '0.4928'}
# {'loss': '0.6', 'grad_norm': '0.3452', 'learning_rate': '2.809e-05', 'epoch': '0.4976'}
# {'loss': '0.6253', 'grad_norm': '0.3401', 'learning_rate': '2.803e-05', 'epoch': '0.5024'}
# {'loss': '0.6631', 'grad_norm': '0.3068', 'learning_rate': '2.797e-05', 'epoch': '0.5072'}
# {'loss': '0.5851', 'grad_norm': '0.3122', 'learning_rate': '2.791e-05', 'epoch': '0.512'}
# {'loss': '0.5876', 'grad_norm': '0.3153', 'learning_rate': '2.784e-05', 'epoch': '0.5167'}
# {'loss': '0.5676', 'grad_norm': '0.3403', 'learning_rate': '2.778e-05', 'epoch': '0.5215'}
# {'loss': '0.6651', 'grad_norm': '0.3338', 'learning_rate': '2.771e-05', 'epoch': '0.5263'}
# {'loss': '0.6382', 'grad_norm': '0.3761', 'learning_rate': '2.764e-05', 'epoch': '0.5311'}
# {'loss': '0.6117', 'grad_norm': '0.3001', 'learning_rate': '2.758e-05', 'epoch': '0.5359'}
# {'loss': '0.61', 'grad_norm': '0.3183', 'learning_rate': '2.751e-05', 'epoch': '0.5407'}
# {'loss': '0.5775', 'grad_norm': '0.3351', 'learning_rate': '2.744e-05', 'epoch': '0.5455'}
# {'loss': '0.6459', 'grad_norm': '0.3471', 'learning_rate': '2.737e-05', 'epoch': '0.5502'}
# {'loss': '0.5998', 'grad_norm': '0.3671', 'learning_rate': '2.73e-05', 'epoch': '0.555'}
# {'loss': '0.6079', 'grad_norm': '0.3288', 'learning_rate': '2.722e-05', 'epoch': '0.5598'}
# {'loss': '0.5652', 'grad_norm': '0.3085', 'learning_rate': '2.715e-05', 'epoch': '0.5646'}
# {'loss': '0.5922', 'grad_norm': '0.3114', 'learning_rate': '2.708e-05', 'epoch': '0.5694'}
#  29% 120/418 [12:10<22:50,  4.60s/it]wandb: WARNING Tried to log to step 120 that is less than the current step 122. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# {'loss': '0.65', 'grad_norm': '0.3658', 'learning_rate': '2.7e-05', 'epoch': '0.5742'}
# {'loss': '0.62', 'grad_norm': '0.3299', 'learning_rate': '2.693e-05', 'epoch': '0.5789'}
# {'loss': '0.5988', 'grad_norm': '0.3287', 'learning_rate': '2.685e-05', 'epoch': '0.5837'}
# {'loss': '0.5953', 'grad_norm': '0.3425', 'learning_rate': '2.677e-05', 'epoch': '0.5885'}
# {'loss': '0.6011', 'grad_norm': '0.3404', 'learning_rate': '2.669e-05', 'epoch': '0.5933'}
# {'loss': '0.598', 'grad_norm': '0.3411', 'learning_rate': '2.662e-05', 'epoch': '0.5981'}
# {'loss': '0.638', 'grad_norm': '0.3609', 'learning_rate': '2.654e-05', 'epoch': '0.6029'}
# {'loss': '0.5892', 'grad_norm': '0.3434', 'learning_rate': '2.645e-05', 'epoch': '0.6077'}
# {'loss': '0.6025', 'grad_norm': '0.3487', 'learning_rate': '2.637e-05', 'epoch': '0.6124'}
# {'loss': '0.585', 'grad_norm': '0.3479', 'learning_rate': '2.629e-05', 'epoch': '0.6172'}
# {'loss': '0.6073', 'grad_norm': '0.3354', 'learning_rate': '2.621e-05', 'epoch': '0.622'}
# {'loss': '0.619', 'grad_norm': '0.3386', 'learning_rate': '2.612e-05', 'epoch': '0.6268'}
# {'loss': '0.62', 'grad_norm': '0.328', 'learning_rate': '2.604e-05', 'epoch': '0.6316'}
# {'loss': '0.6456', 'grad_norm': '0.417', 'learning_rate': '2.596e-05', 'epoch': '0.6364'}
# {'loss': '0.6066', 'grad_norm': '0.3327', 'learning_rate': '2.587e-05', 'epoch': '0.6411'}
# {'loss': '0.5627', 'grad_norm': '0.3473', 'learning_rate': '2.578e-05', 'epoch': '0.6459'}
# {'loss': '0.5796', 'grad_norm': '0.3414', 'learning_rate': '2.569e-05', 'epoch': '0.6507'}
# {'loss': '0.6112', 'grad_norm': '0.3615', 'learning_rate': '2.561e-05', 'epoch': '0.6555'}
# {'loss': '0.5882', 'grad_norm': '0.3264', 'learning_rate': '2.552e-05', 'epoch': '0.6603'}
# {'loss': '0.581', 'grad_norm': '0.444', 'learning_rate': '2.543e-05', 'epoch': '0.6651'}
#  33% 140/418 [13:38<20:44,  4.48s/it]wandb: WARNING Tried to log to step 140 that is less than the current step 142. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# {'loss': '0.6266', 'grad_norm': '0.3365', 'learning_rate': '2.534e-05', 'epoch': '0.6699'}
# {'loss': '0.5826', 'grad_norm': '0.355', 'learning_rate': '2.525e-05', 'epoch': '0.6746'}
# {'loss': '0.6019', 'grad_norm': '0.3623', 'learning_rate': '2.515e-05', 'epoch': '0.6794'}
# {'loss': '0.5646', 'grad_norm': '0.3748', 'learning_rate': '2.506e-05', 'epoch': '0.6842'}
# {'loss': '0.6022', 'grad_norm': '0.3666', 'learning_rate': '2.497e-05', 'epoch': '0.689'}
# {'loss': '0.5477', 'grad_norm': '0.3987', 'learning_rate': '2.487e-05', 'epoch': '0.6938'}
# {'loss': '0.5583', 'grad_norm': '0.3822', 'learning_rate': '2.478e-05', 'epoch': '0.6986'}
# {'loss': '0.5307', 'grad_norm': '0.3623', 'learning_rate': '2.468e-05', 'epoch': '0.7033'}
# {'loss': '0.5775', 'grad_norm': '0.3834', 'learning_rate': '2.459e-05', 'epoch': '0.7081'}
# {'loss': '0.6007', 'grad_norm': '0.3482', 'learning_rate': '2.449e-05', 'epoch': '0.7129'}
# {'loss': '0.5914', 'grad_norm': '0.376', 'learning_rate': '2.439e-05', 'epoch': '0.7177'}
#  36% 150/418 [14:23<20:05,  4.50s/it]
#   0% 0/21 [00:00<?, ?it/s]
#  10% 2/21 [00:02<00:24,  1.31s/it]
#  14% 3/21 [00:04<00:31,  1.73s/it]
#  19% 4/21 [00:07<00:36,  2.12s/it]
#  24% 5/21 [00:09<00:34,  2.16s/it]
#  29% 6/21 [00:12<00:33,  2.24s/it]
#  33% 7/21 [00:15<00:34,  2.47s/it]
#  38% 8/21 [00:18<00:34,  2.68s/it]
#  43% 9/21 [00:20<00:31,  2.64s/it]
#  48% 10/21 [00:24<00:32,  2.94s/it]
#  52% 11/21 [00:27<00:28,  2.89s/it]
#  57% 12/21 [00:30<00:25,  2.84s/it]
#  62% 13/21 [00:32<00:22,  2.81s/it]
#  67% 14/21 [00:35<00:19,  2.81s/it]
#  71% 15/21 [00:38<00:16,  2.79s/it]
#  76% 16/21 [00:41<00:13,  2.79s/it]
#  81% 17/21 [00:43<00:11,  2.80s/it]
#  86% 18/21 [00:46<00:08,  2.79s/it]
#  90% 19/21 [00:49<00:05,  2.80s/it]
#  95% 20/21 [00:52<00:02,  2.75s/it]
#
# {'eval_loss': '0.5948', 'eval_runtime': '56.05', 'eval_samples_per_second': '12.51', 'eval_steps_per_second': '0.392', 'epoch': '0.7177'}
#  36% 150/418 [15:19<20:05,  4.50s/it]
# 100% 21/21 [00:53<00:00,  2.26s/it]2026-07-21 08:45:19 | INFO     | core.callbacks:on_evaluate:58 - New best eval_loss=0.5948 at step 150 -> saving to /content/drive/MyDrive/vlm-finetuning-project1/checkpoints/qwen3vl-2b/unified-sft64-v2-visionlora/best
#
#                                    Unsloth: Restored added_tokens_decoder metadata in /content/drive/MyDrive/vlm-finetuning-project1/checkpoints/qwen3vl-2b/unified-sft64-v2-visionlora/checkpoint-150/tokenizer_config.json.
# {'loss': '0.5624', 'grad_norm': '0.3694', 'learning_rate': '2.43e-05', 'epoch': '0.7225'}
# {'loss': '0.588', 'grad_norm': '0.3918', 'learning_rate': '2.42e-05', 'epoch': '0.7273'}
# {'loss': '0.5662', 'grad_norm': '0.3828', 'learning_rate': '2.41e-05', 'epoch': '0.7321'}
# {'loss': '0.5762', 'grad_norm': '0.3907', 'learning_rate': '2.4e-05', 'epoch': '0.7368'}
# {'loss': '0.575', 'grad_norm': '0.3614', 'learning_rate': '2.39e-05', 'epoch': '0.7416'}
# {'loss': '0.5827', 'grad_norm': '0.3342', 'learning_rate': '2.38e-05', 'epoch': '0.7464'}
# {'loss': '0.5725', 'grad_norm': '0.364', 'learning_rate': '2.369e-05', 'epoch': '0.7512'}
# {'loss': '0.6207', 'grad_norm': '0.3622', 'learning_rate': '2.359e-05', 'epoch': '0.756'}
# {'loss': '0.5525', 'grad_norm': '0.3489', 'learning_rate': '2.349e-05', 'epoch': '0.7608'}
#  38% 160/418 [16:10<22:14,  5.17s/it]wandb: WARNING Tried to log to step 160 that is less than the current step 163. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# {'loss': '0.6431', 'grad_norm': '0.3482', 'learning_rate': '2.339e-05', 'epoch': '0.7656'}
# {'loss': '0.5639', 'grad_norm': '0.3636', 'learning_rate': '2.328e-05', 'epoch': '0.7703'}
# {'loss': '0.5985', 'grad_norm': '0.4321', 'learning_rate': '2.318e-05', 'epoch': '0.7751'}
# {'loss': '0.6234', 'grad_norm': '0.3786', 'learning_rate': '2.307e-05', 'epoch': '0.7799'}
# {'loss': '0.5452', 'grad_norm': '0.3579', 'learning_rate': '2.297e-05', 'epoch': '0.7847'}
# {'loss': '0.6401', 'grad_norm': '0.4062', 'learning_rate': '2.286e-05', 'epoch': '0.7895'}
# {'loss': '0.59', 'grad_norm': '0.3736', 'learning_rate': '2.275e-05', 'epoch': '0.7943'}
# {'loss': '0.5605', 'grad_norm': '0.3335', 'learning_rate': '2.264e-05', 'epoch': '0.799'}
# {'loss': '0.6167', 'grad_norm': '0.3375', 'learning_rate': '2.254e-05', 'epoch': '0.8038'}
# {'loss': '0.5562', 'grad_norm': '0.3353', 'learning_rate': '2.243e-05', 'epoch': '0.8086'}
# {'loss': '0.5456', 'grad_norm': '0.3925', 'learning_rate': '2.232e-05', 'epoch': '0.8134'}
# {'loss': '0.5622', 'grad_norm': '0.3624', 'learning_rate': '2.221e-05', 'epoch': '0.8182'}
# {'loss': '0.5723', 'grad_norm': '0.3602', 'learning_rate': '2.21e-05', 'epoch': '0.823'}
# {'loss': '0.612', 'grad_norm': '0.3649', 'learning_rate': '2.199e-05', 'epoch': '0.8278'}
# {'loss': '0.6328', 'grad_norm': '0.3655', 'learning_rate': '2.188e-05', 'epoch': '0.8325'}
# {'loss': '0.5924', 'grad_norm': '0.4108', 'learning_rate': '2.177e-05', 'epoch': '0.8373'}
# {'loss': '0.607', 'grad_norm': '0.3783', 'learning_rate': '2.165e-05', 'epoch': '0.8421'}
# {'loss': '0.5171', 'grad_norm': '0.3525', 'learning_rate': '2.154e-05', 'epoch': '0.8469'}
# {'loss': '0.5842', 'grad_norm': '0.3466', 'learning_rate': '2.143e-05', 'epoch': '0.8517'}
# {'loss': '0.5795', 'grad_norm': '0.3477', 'learning_rate': '2.131e-05', 'epoch': '0.8565'}
#  43% 180/418 [17:39<17:33,  4.42s/it]wandb: WARNING Tried to log to step 180 that is less than the current step 183. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# {'loss': '0.5665', 'grad_norm': '0.3504', 'learning_rate': '2.12e-05', 'epoch': '0.8612'}
# {'loss': '0.5318', 'grad_norm': '0.3734', 'learning_rate': '2.109e-05', 'epoch': '0.866'}
# {'loss': '0.5491', 'grad_norm': '0.3657', 'learning_rate': '2.097e-05', 'epoch': '0.8708'}
# {'loss': '0.5411', 'grad_norm': '0.372', 'learning_rate': '2.086e-05', 'epoch': '0.8756'}
# {'loss': '0.5787', 'grad_norm': '0.371', 'learning_rate': '2.074e-05', 'epoch': '0.8804'}
# {'loss': '0.5741', 'grad_norm': '0.3649', 'learning_rate': '2.062e-05', 'epoch': '0.8852'}
# {'loss': '0.5893', 'grad_norm': '0.3697', 'learning_rate': '2.051e-05', 'epoch': '0.89'}
# {'loss': '0.5611', 'grad_norm': '0.3641', 'learning_rate': '2.039e-05', 'epoch': '0.8947'}
# {'loss': '0.5968', 'grad_norm': '0.3953', 'learning_rate': '2.027e-05', 'epoch': '0.8995'}
# {'loss': '0.5252', 'grad_norm': '0.3742', 'learning_rate': '2.016e-05', 'epoch': '0.9043'}
# {'loss': '0.6227', 'grad_norm': '0.3857', 'learning_rate': '2.004e-05', 'epoch': '0.9091'}
# {'loss': '0.5811', 'grad_norm': '0.3667', 'learning_rate': '1.992e-05', 'epoch': '0.9139'}
# {'loss': '0.5889', 'grad_norm': '0.3654', 'learning_rate': '1.98e-05', 'epoch': '0.9187'}
# {'loss': '0.5965', 'grad_norm': '0.3519', 'learning_rate': '1.968e-05', 'epoch': '0.9234'}
# {'loss': '0.5621', 'grad_norm': '0.3668', 'learning_rate': '1.956e-05', 'epoch': '0.9282'}
# {'loss': '0.5608', 'grad_norm': '0.3583', 'learning_rate': '1.944e-05', 'epoch': '0.933'}
# {'loss': '0.5524', 'grad_norm': '0.3747', 'learning_rate': '1.932e-05', 'epoch': '0.9378'}
# {'loss': '0.551', 'grad_norm': '0.3703', 'learning_rate': '1.92e-05', 'epoch': '0.9426'}
# {'loss': '0.5622', 'grad_norm': '0.38', 'learning_rate': '1.908e-05', 'epoch': '0.9474'}
# {'loss': '0.5695', 'grad_norm': '0.4062', 'learning_rate': '1.896e-05', 'epoch': '0.9522'}
#  48% 200/418 [19:06<16:00,  4.41s/it]wandb: WARNING Tried to log to step 200 that is less than the current step 203. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# {'loss': '0.5996', 'grad_norm': '0.3771', 'learning_rate': '1.884e-05', 'epoch': '0.9569'}
#  48% 200/418 [19:06<16:00,  4.41s/it]
#   0% 0/21 [00:00<?, ?it/s]
#  10% 2/21 [00:02<00:24,  1.28s/it]
#  14% 3/21 [00:04<00:29,  1.64s/it]
#  19% 4/21 [00:07<00:33,  1.96s/it]
#  24% 5/21 [00:09<00:35,  2.21s/it]
#  29% 6/21 [00:12<00:34,  2.27s/it]
#  33% 7/21 [00:14<00:33,  2.41s/it]
#  38% 8/21 [00:17<00:32,  2.54s/it]
#  43% 9/21 [00:20<00:32,  2.74s/it]
#  48% 10/21 [00:23<00:30,  2.81s/it]
#  52% 11/21 [00:26<00:27,  2.75s/it]
#  57% 12/21 [00:29<00:25,  2.81s/it]
#  62% 13/21 [00:32<00:22,  2.81s/it]
#  67% 14/21 [00:35<00:19,  2.81s/it]
#  71% 15/21 [00:37<00:16,  2.80s/it]
#  76% 16/21 [00:40<00:13,  2.78s/it]
#  81% 17/21 [00:43<00:11,  2.80s/it]
#  86% 18/21 [00:46<00:08,  2.81s/it]
#  90% 19/21 [00:49<00:05,  2.79s/it]
#  95% 20/21 [00:51<00:02,  2.69s/it]
#
# {'eval_loss': '0.5791', 'eval_runtime': '55.35', 'eval_samples_per_second': '12.67', 'eval_steps_per_second': '0.397', 'epoch': '0.9569'}
#  48% 200/418 [20:01<16:00,  4.41s/it]
# 100% 21/21 [00:53<00:00,  2.22s/it]2026-07-21 08:50:01 | INFO     | core.callbacks:on_evaluate:58 - New best eval_loss=0.5791 at step 200 -> saving to /content/drive/MyDrive/vlm-finetuning-project1/checkpoints/qwen3vl-2b/unified-sft64-v2-visionlora/best
#
#                                    Unsloth: Restored added_tokens_decoder metadata in /content/drive/MyDrive/vlm-finetuning-project1/checkpoints/qwen3vl-2b/unified-sft64-v2-visionlora/checkpoint-200/tokenizer_config.json.
# {'loss': '0.52', 'grad_norm': '0.3728', 'learning_rate': '1.872e-05', 'epoch': '0.9617'}
# {'loss': '0.6468', 'grad_norm': '0.3636', 'learning_rate': '1.86e-05', 'epoch': '0.9665'}
# {'loss': '0.5944', 'grad_norm': '0.389', 'learning_rate': '1.848e-05', 'epoch': '0.9713'}
# {'loss': '0.5577', 'grad_norm': '0.3474', 'learning_rate': '1.836e-05', 'epoch': '0.9761'}
# {'loss': '0.6124', 'grad_norm': '0.3648', 'learning_rate': '1.823e-05', 'epoch': '0.9809'}
# {'loss': '0.5949', 'grad_norm': '0.3524', 'learning_rate': '1.811e-05', 'epoch': '0.9856'}
# {'loss': '0.5241', 'grad_norm': '0.3725', 'learning_rate': '1.799e-05', 'epoch': '0.9904'}
# {'loss': '0.5663', 'grad_norm': '0.3733', 'learning_rate': '1.786e-05', 'epoch': '0.9952'}
# {'loss': '0.569', 'grad_norm': '0.3732', 'learning_rate': '1.774e-05', 'epoch': '1'}
# {'loss': '0.5445', 'grad_norm': '0.3538', 'learning_rate': '1.762e-05', 'epoch': '1.005'}
# {'loss': '0.5826', 'grad_norm': '0.3631', 'learning_rate': '1.749e-05', 'epoch': '1.01'}
# {'loss': '0.5613', 'grad_norm': '0.3576', 'learning_rate': '1.737e-05', 'epoch': '1.014'}
# {'loss': '0.554', 'grad_norm': '0.3836', 'learning_rate': '1.725e-05', 'epoch': '1.019'}
# {'loss': '0.5869', 'grad_norm': '0.3802', 'learning_rate': '1.712e-05', 'epoch': '1.024'}
# {'loss': '0.5942', 'grad_norm': '0.4092', 'learning_rate': '1.7e-05', 'epoch': '1.029'}
# {'loss': '0.5558', 'grad_norm': '0.3537', 'learning_rate': '1.688e-05', 'epoch': '1.033'}
# {'loss': '0.5521', 'grad_norm': '0.3869', 'learning_rate': '1.675e-05', 'epoch': '1.038'}
# {'loss': '0.5284', 'grad_norm': '0.3749', 'learning_rate': '1.663e-05', 'epoch': '1.043'}
# {'loss': '0.5356', 'grad_norm': '0.3878', 'learning_rate': '1.65e-05', 'epoch': '1.048'}
#  53% 220/418 [21:38<14:53,  4.51s/it]wandb: WARNING Tried to log to step 220 that is less than the current step 224. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# {'loss': '0.58', 'grad_norm': '0.3816', 'learning_rate': '1.638e-05', 'epoch': '1.053'}
# {'loss': '0.5421', 'grad_norm': '0.3557', 'learning_rate': '1.625e-05', 'epoch': '1.057'}
# {'loss': '0.5438', 'grad_norm': '0.3806', 'learning_rate': '1.613e-05', 'epoch': '1.062'}
# {'loss': '0.5511', 'grad_norm': '0.3797', 'learning_rate': '1.6e-05', 'epoch': '1.067'}
# {'loss': '0.5834', 'grad_norm': '0.3505', 'learning_rate': '1.588e-05', 'epoch': '1.072'}
# {'loss': '0.5976', 'grad_norm': '0.4009', 'learning_rate': '1.575e-05', 'epoch': '1.077'}
# {'loss': '0.5461', 'grad_norm': '0.4175', 'learning_rate': '1.563e-05', 'epoch': '1.081'}
# {'loss': '0.5683', 'grad_norm': '0.3802', 'learning_rate': '1.55e-05', 'epoch': '1.086'}
# {'loss': '0.5911', 'grad_norm': '0.3892', 'learning_rate': '1.538e-05', 'epoch': '1.091'}
# {'loss': '0.5818', 'grad_norm': '0.4048', 'learning_rate': '1.525e-05', 'epoch': '1.096'}
# {'loss': '0.579', 'grad_norm': '0.3987', 'learning_rate': '1.513e-05', 'epoch': '1.1'}
# {'loss': '0.5617', 'grad_norm': '0.4062', 'learning_rate': '1.5e-05', 'epoch': '1.105'}
# {'loss': '0.5469', 'grad_norm': '0.3988', 'learning_rate': '1.487e-05', 'epoch': '1.11'}
# {'loss': '0.5811', 'grad_norm': '0.3862', 'learning_rate': '1.475e-05', 'epoch': '1.115'}
# {'loss': '0.5273', 'grad_norm': '0.3769', 'learning_rate': '1.462e-05', 'epoch': '1.12'}
# {'loss': '0.5508', 'grad_norm': '0.4078', 'learning_rate': '1.45e-05', 'epoch': '1.124'}
# {'loss': '0.5742', 'grad_norm': '0.4251', 'learning_rate': '1.437e-05', 'epoch': '1.129'}
# {'loss': '0.5996', 'grad_norm': '0.3855', 'learning_rate': '1.425e-05', 'epoch': '1.134'}
# {'loss': '0.5538', 'grad_norm': '0.4139', 'learning_rate': '1.412e-05', 'epoch': '1.139'}
# {'loss': '0.5651', 'grad_norm': '0.3427', 'learning_rate': '1.4e-05', 'epoch': '1.144'}
#  57% 240/418 [23:09<13:02,  4.40s/it]wandb: WARNING Tried to log to step 240 that is less than the current step 244. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# {'loss': '0.5577', 'grad_norm': '0.3732', 'learning_rate': '1.387e-05', 'epoch': '1.148'}
# {'loss': '0.5403', 'grad_norm': '0.3936', 'learning_rate': '1.375e-05', 'epoch': '1.153'}
# {'loss': '0.5795', 'grad_norm': '0.3623', 'learning_rate': '1.362e-05', 'epoch': '1.158'}
# {'loss': '0.5383', 'grad_norm': '0.4363', 'learning_rate': '1.35e-05', 'epoch': '1.163'}
# {'loss': '0.5628', 'grad_norm': '0.3809', 'learning_rate': '1.337e-05', 'epoch': '1.167'}
# {'loss': '0.5748', 'grad_norm': '0.3948', 'learning_rate': '1.325e-05', 'epoch': '1.172'}
# {'loss': '0.5926', 'grad_norm': '0.3786', 'learning_rate': '1.312e-05', 'epoch': '1.177'}
# {'loss': '0.5411', 'grad_norm': '0.3741', 'learning_rate': '1.3e-05', 'epoch': '1.182'}
# {'loss': '0.5368', 'grad_norm': '0.381', 'learning_rate': '1.288e-05', 'epoch': '1.187'}
# {'loss': '0.5978', 'grad_norm': '0.4068', 'learning_rate': '1.275e-05', 'epoch': '1.191'}
# {'loss': '0.5789', 'grad_norm': '0.395', 'learning_rate': '1.263e-05', 'epoch': '1.196'}
#  60% 250/418 [23:55<12:51,  4.59s/it]
#   0% 0/21 [00:00<?, ?it/s]
#  10% 2/21 [00:02<00:24,  1.27s/it]
#  14% 3/21 [00:04<00:30,  1.71s/it]
#  19% 4/21 [00:07<00:35,  2.10s/it]
#  24% 5/21 [00:10<00:36,  2.26s/it]
#  29% 6/21 [00:12<00:35,  2.40s/it]
#  33% 7/21 [00:15<00:34,  2.49s/it]
#  38% 8/21 [00:18<00:34,  2.62s/it]
#  43% 9/21 [00:21<00:32,  2.70s/it]
#  48% 10/21 [00:24<00:30,  2.73s/it]
#  52% 11/21 [00:26<00:27,  2.74s/it]
#  57% 12/21 [00:29<00:24,  2.74s/it]
#  62% 13/21 [00:32<00:22,  2.75s/it]
#  67% 14/21 [00:35<00:19,  2.77s/it]
#  71% 15/21 [00:38<00:16,  2.77s/it]
#  76% 16/21 [00:40<00:13,  2.77s/it]
#  81% 17/21 [00:43<00:11,  2.79s/it]
#  86% 18/21 [00:46<00:08,  2.86s/it]
#  90% 19/21 [00:49<00:05,  2.91s/it]
#  95% 20/21 [00:52<00:02,  2.75s/it]
#
# {'eval_loss': '0.5692', 'eval_runtime': '55.88', 'eval_samples_per_second': '12.55', 'eval_steps_per_second': '0.394', 'epoch': '1.196'}
#  60% 250/418 [24:50<12:51,  4.59s/it]
# 100% 21/21 [00:53<00:00,  2.26s/it]2026-07-21 08:54:50 | INFO     | core.callbacks:on_evaluate:58 - New best eval_loss=0.5692 at step 250 -> saving to /content/drive/MyDrive/vlm-finetuning-project1/checkpoints/qwen3vl-2b/unified-sft64-v2-visionlora/best
#
#                                    Unsloth: Restored added_tokens_decoder metadata in /content/drive/MyDrive/vlm-finetuning-project1/checkpoints/qwen3vl-2b/unified-sft64-v2-visionlora/checkpoint-250/tokenizer_config.json.
# {'loss': '0.5622', 'grad_norm': '0.3628', 'learning_rate': '1.251e-05', 'epoch': '1.201'}
# {'loss': '0.5657', 'grad_norm': '0.41', 'learning_rate': '1.238e-05', 'epoch': '1.206'}
# {'loss': '0.4943', 'grad_norm': '0.3699', 'learning_rate': '1.226e-05', 'epoch': '1.211'}
# {'loss': '0.5537', 'grad_norm': '0.385', 'learning_rate': '1.214e-05', 'epoch': '1.215'}
# {'loss': '0.572', 'grad_norm': '0.4043', 'learning_rate': '1.201e-05', 'epoch': '1.22'}
# {'loss': '0.5456', 'grad_norm': '0.3868', 'learning_rate': '1.189e-05', 'epoch': '1.225'}
# {'loss': '0.5469', 'grad_norm': '0.3558', 'learning_rate': '1.177e-05', 'epoch': '1.23'}
# {'loss': '0.537', 'grad_norm': '0.4245', 'learning_rate': '1.164e-05', 'epoch': '1.234'}
# {'loss': '0.4988', 'grad_norm': '0.419', 'learning_rate': '1.152e-05', 'epoch': '1.239'}
#  62% 260/418 [25:42<13:48,  5.25s/it]wandb: WARNING Tried to log to step 260 that is less than the current step 265. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# {'loss': '0.5775', 'grad_norm': '0.3773', 'learning_rate': '1.14e-05', 'epoch': '1.244'}
# {'loss': '0.5579', 'grad_norm': '0.3833', 'learning_rate': '1.128e-05', 'epoch': '1.249'}
# {'loss': '0.5559', 'grad_norm': '0.417', 'learning_rate': '1.116e-05', 'epoch': '1.254'}
# {'loss': '0.4985', 'grad_norm': '0.3849', 'learning_rate': '1.104e-05', 'epoch': '1.258'}
# {'loss': '0.5809', 'grad_norm': '0.4283', 'learning_rate': '1.092e-05', 'epoch': '1.263'}
# {'loss': '0.5573', 'grad_norm': '0.3721', 'learning_rate': '1.08e-05', 'epoch': '1.268'}
# {'loss': '0.5577', 'grad_norm': '0.388', 'learning_rate': '1.068e-05', 'epoch': '1.273'}
# {'loss': '0.5507', 'grad_norm': '0.3893', 'learning_rate': '1.056e-05', 'epoch': '1.278'}
# {'loss': '0.5142', 'grad_norm': '0.4536', 'learning_rate': '1.044e-05', 'epoch': '1.282'}
# {'loss': '0.5396', 'grad_norm': '0.4144', 'learning_rate': '1.032e-05', 'epoch': '1.287'}
# {'loss': '0.5215', 'grad_norm': '0.4006', 'learning_rate': '1.02e-05', 'epoch': '1.292'}
# {'loss': '0.5904', 'grad_norm': '0.3872', 'learning_rate': '1.008e-05', 'epoch': '1.297'}
# {'loss': '0.5203', 'grad_norm': '0.4351', 'learning_rate': '9.961e-06', 'epoch': '1.301'}
# {'loss': '0.535', 'grad_norm': '0.3859', 'learning_rate': '9.844e-06', 'epoch': '1.306'}
# {'loss': '0.5487', 'grad_norm': '0.4436', 'learning_rate': '9.726e-06', 'epoch': '1.311'}
# {'loss': '0.5331', 'grad_norm': '0.4524', 'learning_rate': '9.609e-06', 'epoch': '1.316'}
# {'loss': '0.5706', 'grad_norm': '0.4242', 'learning_rate': '9.492e-06', 'epoch': '1.321'}
# {'loss': '0.5165', 'grad_norm': '0.4112', 'learning_rate': '9.376e-06', 'epoch': '1.325'}
# {'loss': '0.5412', 'grad_norm': '0.4268', 'learning_rate': '9.26e-06', 'epoch': '1.33'}
# {'loss': '0.5185', 'grad_norm': '0.4057', 'learning_rate': '9.144e-06', 'epoch': '1.335'}
#  67% 280/418 [27:09<10:08,  4.41s/it]wandb: WARNING Tried to log to step 280 that is less than the current step 285. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# {'loss': '0.5651', 'grad_norm': '0.4026', 'learning_rate': '9.029e-06', 'epoch': '1.34'}
# {'loss': '0.4643', 'grad_norm': '0.3882', 'learning_rate': '8.914e-06', 'epoch': '1.344'}
# {'loss': '0.5434', 'grad_norm': '0.4003', 'learning_rate': '8.8e-06', 'epoch': '1.349'}
# {'loss': '0.5607', 'grad_norm': '0.4131', 'learning_rate': '8.686e-06', 'epoch': '1.354'}
# {'loss': '0.5541', 'grad_norm': '0.3904', 'learning_rate': '8.573e-06', 'epoch': '1.359'}
# {'loss': '0.5432', 'grad_norm': '0.3913', 'learning_rate': '8.46e-06', 'epoch': '1.364'}
# {'loss': '0.5541', 'grad_norm': '0.3842', 'learning_rate': '8.347e-06', 'epoch': '1.368'}
# {'loss': '0.5731', 'grad_norm': '0.4411', 'learning_rate': '8.235e-06', 'epoch': '1.373'}
# {'loss': '0.5885', 'grad_norm': '0.4176', 'learning_rate': '8.123e-06', 'epoch': '1.378'}
# {'loss': '0.6001', 'grad_norm': '0.4167', 'learning_rate': '8.012e-06', 'epoch': '1.383'}
# {'loss': '0.5442', 'grad_norm': '0.3865', 'learning_rate': '7.901e-06', 'epoch': '1.388'}
# {'loss': '0.5089', 'grad_norm': '0.3895', 'learning_rate': '7.791e-06', 'epoch': '1.392'}
# {'loss': '0.4923', 'grad_norm': '0.447', 'learning_rate': '7.682e-06', 'epoch': '1.397'}
# {'loss': '0.5436', 'grad_norm': '0.4154', 'learning_rate': '7.572e-06', 'epoch': '1.402'}
# {'loss': '0.4935', 'grad_norm': '0.383', 'learning_rate': '7.464e-06', 'epoch': '1.407'}
# {'loss': '0.5504', 'grad_norm': '0.4063', 'learning_rate': '7.356e-06', 'epoch': '1.411'}
# {'loss': '0.5381', 'grad_norm': '0.4355', 'learning_rate': '7.248e-06', 'epoch': '1.416'}
# {'loss': '0.4819', 'grad_norm': '0.4004', 'learning_rate': '7.141e-06', 'epoch': '1.421'}
# {'loss': '0.6229', 'grad_norm': '0.4143', 'learning_rate': '7.035e-06', 'epoch': '1.426'}
# {'loss': '0.5429', 'grad_norm': '0.3769', 'learning_rate': '6.929e-06', 'epoch': '1.431'}
#  72% 300/418 [28:37<08:33,  4.35s/it]wandb: WARNING Tried to log to step 300 that is less than the current step 305. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# {'loss': '0.5326', 'grad_norm': '0.3766', 'learning_rate': '6.823e-06', 'epoch': '1.435'}
#  72% 300/418 [28:37<08:33,  4.35s/it]
#   0% 0/21 [00:00<?, ?it/s]
#  10% 2/21 [00:02<00:23,  1.26s/it]
#  14% 3/21 [00:04<00:31,  1.73s/it]
#  19% 4/21 [00:07<00:35,  2.09s/it]
#  24% 5/21 [00:09<00:34,  2.15s/it]
#  29% 6/21 [00:12<00:33,  2.22s/it]
#  33% 7/21 [00:15<00:34,  2.45s/it]
#  38% 8/21 [00:18<00:34,  2.67s/it]
#  43% 9/21 [00:20<00:31,  2.65s/it]
#  48% 10/21 [00:23<00:30,  2.76s/it]
#  52% 11/21 [00:26<00:27,  2.76s/it]
#  57% 12/21 [00:29<00:24,  2.76s/it]
#  62% 13/21 [00:32<00:22,  2.78s/it]
#  67% 14/21 [00:35<00:19,  2.78s/it]
#  71% 15/21 [00:37<00:16,  2.77s/it]
#  76% 16/21 [00:40<00:13,  2.77s/it]
#  81% 17/21 [00:43<00:11,  2.80s/it]
#  86% 18/21 [00:46<00:08,  2.80s/it]
#  90% 19/21 [00:49<00:05,  2.79s/it]
#  95% 20/21 [00:51<00:02,  2.69s/it]
#
# {'eval_loss': '0.5647', 'eval_runtime': '55.35', 'eval_samples_per_second': '12.66', 'eval_steps_per_second': '0.397', 'epoch': '1.435'}
#  72% 300/418 [29:32<08:33,  4.35s/it]
# 100% 21/21 [00:52<00:00,  2.22s/it]
#                                    Unsloth: Restored added_tokens_decoder metadata in /content/drive/MyDrive/vlm-finetuning-project1/checkpoints/qwen3vl-2b/unified-sft64-v2-visionlora/checkpoint-300/tokenizer_config.json.
# {'loss': '0.5629', 'grad_norm': '0.3969', 'learning_rate': '6.719e-06', 'epoch': '1.44'}
# {'loss': '0.5071', 'grad_norm': '0.3945', 'learning_rate': '6.614e-06', 'epoch': '1.445'}
# {'loss': '0.5667', 'grad_norm': '0.38', 'learning_rate': '6.511e-06', 'epoch': '1.45'}
# {'loss': '0.502', 'grad_norm': '0.4464', 'learning_rate': '6.408e-06', 'epoch': '1.455'}
# {'loss': '0.5715', 'grad_norm': '0.4249', 'learning_rate': '6.305e-06', 'epoch': '1.459'}
# {'loss': '0.6069', 'grad_norm': '0.4218', 'learning_rate': '6.204e-06', 'epoch': '1.464'}
# {'loss': '0.5495', 'grad_norm': '0.4052', 'learning_rate': '6.102e-06', 'epoch': '1.469'}
# {'loss': '0.5346', 'grad_norm': '0.4367', 'learning_rate': '6.002e-06', 'epoch': '1.474'}
# {'loss': '0.5935', 'grad_norm': '0.43', 'learning_rate': '5.902e-06', 'epoch': '1.478'}
# {'loss': '0.5424', 'grad_norm': '0.4045', 'learning_rate': '5.802e-06', 'epoch': '1.483'}
# {'loss': '0.5482', 'grad_norm': '0.4215', 'learning_rate': '5.704e-06', 'epoch': '1.488'}
# {'loss': '0.5235', 'grad_norm': '0.4159', 'learning_rate': '5.606e-06', 'epoch': '1.493'}
# {'loss': '0.5333', 'grad_norm': '0.4094', 'learning_rate': '5.508e-06', 'epoch': '1.498'}
# {'loss': '0.5472', 'grad_norm': '0.4306', 'learning_rate': '5.412e-06', 'epoch': '1.502'}
# {'loss': '0.5893', 'grad_norm': '0.4336', 'learning_rate': '5.316e-06', 'epoch': '1.507'}
# {'loss': '0.5164', 'grad_norm': '0.3824', 'learning_rate': '5.22e-06', 'epoch': '1.512'}
# {'loss': '0.5164', 'grad_norm': '0.4001', 'learning_rate': '5.126e-06', 'epoch': '1.517'}
# {'loss': '0.503', 'grad_norm': '0.4202', 'learning_rate': '5.032e-06', 'epoch': '1.522'}
# {'loss': '0.5926', 'grad_norm': '0.4143', 'learning_rate': '4.938e-06', 'epoch': '1.526'}
#  77% 320/418 [31:04<07:01,  4.30s/it]wandb: WARNING Tried to log to step 320 that is less than the current step 326. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# {'loss': '0.5596', 'grad_norm': '0.4033', 'learning_rate': '4.846e-06', 'epoch': '1.531'}
# {'loss': '0.5431', 'grad_norm': '0.3819', 'learning_rate': '4.754e-06', 'epoch': '1.536'}
# {'loss': '0.5388', 'grad_norm': '0.3987', 'learning_rate': '4.663e-06', 'epoch': '1.541'}
# {'loss': '0.5077', 'grad_norm': '0.3918', 'learning_rate': '4.572e-06', 'epoch': '1.545'}
# {'loss': '0.5718', 'grad_norm': '0.4178', 'learning_rate': '4.482e-06', 'epoch': '1.55'}
# {'loss': '0.5356', 'grad_norm': '0.4008', 'learning_rate': '4.393e-06', 'epoch': '1.555'}
# {'loss': '0.5452', 'grad_norm': '0.4179', 'learning_rate': '4.305e-06', 'epoch': '1.56'}
# {'loss': '0.4996', 'grad_norm': '0.3847', 'learning_rate': '4.218e-06', 'epoch': '1.565'}
# {'loss': '0.5283', 'grad_norm': '0.3861', 'learning_rate': '4.131e-06', 'epoch': '1.569'}
# {'loss': '0.5694', 'grad_norm': '0.4285', 'learning_rate': '4.045e-06', 'epoch': '1.574'}
# {'loss': '0.5519', 'grad_norm': '0.3866', 'learning_rate': '3.96e-06', 'epoch': '1.579'}
# {'loss': '0.5367', 'grad_norm': '0.3927', 'learning_rate': '3.875e-06', 'epoch': '1.584'}
# ...
# {'loss': '0.5601', 'grad_norm': '0.4443', 'learning_rate': '2.705e-06', 'epoch': '1.656'}
# {'loss': '0.5341', 'grad_norm': '0.4138', 'learning_rate': '2.633e-06', 'epoch': '1.66'}
# {'loss': '0.5221', 'grad_norm': '0.3943', 'learning_rate': '2.563e-06', 'epoch': '1.665'}
# {'loss': '0.5662', 'grad_norm': '0.3739', 'learning_rate': '2.493e-06', 'epoch': '1.67'}
# {'loss': '0.5293', 'grad_norm': '0.3852', 'learning_rate': '2.424e-06', 'epoch': '1.675'}
#  84% 350/418 [33:19<05:04,  4.47s/it]
#   0% 0/21 [00:00<?, ?it/s]
#  10% 2/21 [00:02<00:22,  1.18s/it]
#  14% 3/21 [00:04<00:29,  1.67s/it]
#  19% 4/21 [00:07<00:33,  1.96s/it]
#  24% 5/21 [00:09<00:34,  2.17s/it]
#  29% 6/21 [00:12<00:33,  2.24s/it]
#  33% 7/21 [00:14<00:33,  2.39s/it]
#  38% 8/21 [00:17<00:32,  2.52s/it]
#  43% 9/21 [00:20<00:31,  2.62s/it]
#  48% 10/21 [00:23<00:29,  2.68s/it]
#  52% 11/21 [00:26<00:27,  2.70s/it]
#  57% 12/21 [00:28<00:24,  2.72s/it]
#  62% 13/21 [00:31<00:21,  2.73s/it]
#  67% 14/21 [00:34<00:19,  2.75s/it]
#  71% 15/21 [00:37<00:17,  2.84s/it]
#  76% 16/21 [00:40<00:14,  2.91s/it]
#  81% 17/21 [00:43<00:11,  2.83s/it]
#  86% 18/21 [00:46<00:08,  2.89s/it]
#  90% 19/21 [00:48<00:05,  2.85s/it]
#  95% 20/21 [00:51<00:02,  2.80s/it]
#
# {'eval_loss': '0.5609', 'eval_runtime': '55.45', 'eval_samples_per_second': '12.64', 'eval_steps_per_second': '0.397', 'epoch': '1.675'}
#  84% 350/418 [34:14<05:04,  4.47s/it]
# 100% 21/21 [00:53<00:00,  2.30s/it]2026-07-21 09:04:14 | INFO     | core.callbacks:on_evaluate:58 - New best eval_loss=0.5609 at step 350 -> saving to /content/drive/MyDrive/vlm-finetuning-project1/checkpoints/qwen3vl-2b/unified-sft64-v2-visionlora/best
#
#                                    Unsloth: Restored added_tokens_decoder metadata in /content/drive/MyDrive/vlm-finetuning-project1/checkpoints/qwen3vl-2b/unified-sft64-v2-visionlora/checkpoint-350/tokenizer_config.json.
# {'loss': '0.5448', 'grad_norm': '0.4026', 'learning_rate': '2.357e-06', 'epoch': '1.679'}
# {'loss': '0.5134', 'grad_norm': '0.4205', 'learning_rate': '2.29e-06', 'epoch': '1.684'}
# {'loss': '0.548', 'grad_norm': '0.4161', 'learning_rate': '2.224e-06', 'epoch': '1.689'}
# {'loss': '0.4952', 'grad_norm': '0.4094', 'learning_rate': '2.158e-06', 'epoch': '1.694'}
# {'loss': '0.5073', 'grad_norm': '0.4485', 'learning_rate': '2.094e-06', 'epoch': '1.699'}
# {'loss': '0.4844', 'grad_norm': '0.4339', 'learning_rate': '2.031e-06', 'epoch': '1.703'}
# {'loss': '0.5198', 'grad_norm': '0.4096', 'learning_rate': '1.968e-06', 'epoch': '1.708'}
# {'loss': '0.5524', 'grad_norm': '0.4289', 'learning_rate': '1.906e-06', 'epoch': '1.713'}
# {'loss': '0.5411', 'grad_norm': '0.3994', 'learning_rate': '1.846e-06', 'epoch': '1.718'}
#  86% 360/418 [35:06<05:00,  5.18s/it]wandb: WARNING Tried to log to step 360 that is less than the current step 367. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# {'loss': '0.5153', 'grad_norm': '0.4081', 'learning_rate': '1.786e-06', 'epoch': '1.722'}
# {'loss': '0.5346', 'grad_norm': '0.4129', 'learning_rate': '1.727e-06', 'epoch': '1.727'}
# {'loss': '0.517', 'grad_norm': '0.4097', 'learning_rate': '1.669e-06', 'epoch': '1.732'}
# {'loss': '0.5284', 'grad_norm': '0.4079', 'learning_rate': '1.612e-06', 'epoch': '1.737'}
# {'loss': '0.5313', 'grad_norm': '0.4194', 'learning_rate': '1.556e-06', 'epoch': '1.742'}
# {'loss': '0.5465', 'grad_norm': '0.3874', 'learning_rate': '1.501e-06', 'epoch': '1.746'}
# {'loss': '0.525', 'grad_norm': '0.4099', 'learning_rate': '1.447e-06', 'epoch': '1.751'}
# {'loss': '0.5738', 'grad_norm': '0.3948', 'learning_rate': '1.394e-06', 'epoch': '1.756'}
# {'loss': '0.5072', 'grad_norm': '0.4106', 'learning_rate': '1.341e-06', 'epoch': '1.761'}
# {'loss': '0.595', 'grad_norm': '0.4095', 'learning_rate': '1.29e-06', 'epoch': '1.766'}
# {'loss': '0.511', 'grad_norm': '0.398', 'learning_rate': '1.24e-06', 'epoch': '1.77'}
# {'loss': '0.5479', 'grad_norm': '0.4774', 'learning_rate': '1.19e-06', 'epoch': '1.775'}
# {'loss': '0.5736', 'grad_norm': '0.4147', 'learning_rate': '1.142e-06', 'epoch': '1.78'}
# {'loss': '0.5039', 'grad_norm': '0.4143', 'learning_rate': '1.094e-06', 'epoch': '1.785'}
# {'loss': '0.594', 'grad_norm': '0.4651', 'learning_rate': '1.048e-06', 'epoch': '1.789'}
# {'loss': '0.5441', 'grad_norm': '0.4074', 'learning_rate': '1.002e-06', 'epoch': '1.794'}
# {'loss': '0.5228', 'grad_norm': '0.414', 'learning_rate': '9.577e-07', 'epoch': '1.799'}
# {'loss': '0.5747', 'grad_norm': '0.4095', 'learning_rate': '9.142e-07', 'epoch': '1.804'}
# {'loss': '0.5132', 'grad_norm': '0.3896', 'learning_rate': '8.716e-07', 'epoch': '1.809'}
# {'loss': '0.4959', 'grad_norm': '0.4223', 'learning_rate': '8.3e-07', 'epoch': '1.813'}
#  91% 380/418 [36:33<02:40,  4.22s/it]wandb: WARNING Tried to log to step 380 that is less than the current step 387. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# {'loss': '0.521', 'grad_norm': '0.3958', 'learning_rate': '7.893e-07', 'epoch': '1.818'}
# {'loss': '0.5266', 'grad_norm': '0.3939', 'learning_rate': '7.497e-07', 'epoch': '1.823'}
# {'loss': '0.5688', 'grad_norm': '0.4103', 'learning_rate': '7.111e-07', 'epoch': '1.828'}
# {'loss': '0.5947', 'grad_norm': '0.4203', 'learning_rate': '6.735e-07', 'epoch': '1.833'}
# {'loss': '0.5507', 'grad_norm': '0.4358', 'learning_rate': '6.368e-07', 'epoch': '1.837'}
# {'loss': '0.5633', 'grad_norm': '0.4294', 'learning_rate': '6.012e-07', 'epoch': '1.842'}
# {'loss': '0.4848', 'grad_norm': '0.4005', 'learning_rate': '5.666e-07', 'epoch': '1.847'}
# {'loss': '0.5429', 'grad_norm': '0.3889', 'learning_rate': '5.33e-07', 'epoch': '1.852'}
# {'loss': '0.5427', 'grad_norm': '0.3879', 'learning_rate': '5.004e-07', 'epoch': '1.856'}
# {'loss': '0.5288', 'grad_norm': '0.4024', 'learning_rate': '4.688e-07', 'epoch': '1.861'}
# {'loss': '0.4877', 'grad_norm': '0.4013', 'learning_rate': '4.382e-07', 'epoch': '1.866'}
# {'loss': '0.5094', 'grad_norm': '0.3881', 'learning_rate': '4.086e-07', 'epoch': '1.871'}
# {'loss': '0.5017', 'grad_norm': '0.4555', 'learning_rate': '3.801e-07', 'epoch': '1.876'}
# {'loss': '0.5446', 'grad_norm': '0.3866', 'learning_rate': '3.526e-07', 'epoch': '1.88'}
# {'loss': '0.5323', 'grad_norm': '0.409', 'learning_rate': '3.261e-07', 'epoch': '1.885'}
# {'loss': '0.5519', 'grad_norm': '0.4344', 'learning_rate': '3.006e-07', 'epoch': '1.89'}
# {'loss': '0.5221', 'grad_norm': '0.3966', 'learning_rate': '2.761e-07', 'epoch': '1.895'}
# {'loss': '0.5583', 'grad_norm': '0.4314', 'learning_rate': '2.527e-07', 'epoch': '1.9'}
# {'loss': '0.4893', 'grad_norm': '0.3911', 'learning_rate': '2.303e-07', 'epoch': '1.904'}
# {'loss': '0.5808', 'grad_norm': '0.4052', 'learning_rate': '2.089e-07', 'epoch': '1.909'}
#  96% 400/418 [38:01<01:17,  4.29s/it]wandb: WARNING Tried to log to step 400 that is less than the current step 407. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# {'loss': '0.544', 'grad_norm': '0.3933', 'learning_rate': '1.886e-07', 'epoch': '1.914'}
#  96% 400/418 [38:01<01:17,  4.29s/it]
#   0% 0/21 [00:00<?, ?it/s]
#  10% 2/21 [00:02<00:22,  1.18s/it]
#  14% 3/21 [00:04<00:30,  1.69s/it]
#  19% 4/21 [00:07<00:33,  1.98s/it]
#  24% 5/21 [00:09<00:35,  2.24s/it]
#  29% 6/21 [00:12<00:34,  2.31s/it]
#  33% 7/21 [00:15<00:34,  2.46s/it]
#  38% 8/21 [00:17<00:33,  2.56s/it]
#  43% 9/21 [00:20<00:31,  2.65s/it]
#  48% 10/21 [00:23<00:29,  2.71s/it]
#  52% 11/21 [00:26<00:27,  2.74s/it]
#  57% 12/21 [00:29<00:24,  2.74s/it]
#  62% 13/21 [00:31<00:21,  2.75s/it]
#  67% 14/21 [00:34<00:19,  2.77s/it]
#  71% 15/21 [00:37<00:16,  2.78s/it]
#  76% 16/21 [00:40<00:13,  2.78s/it]
#  81% 17/21 [00:43<00:11,  2.87s/it]
#  86% 18/21 [00:46<00:08,  2.93s/it]
#  90% 19/21 [00:49<00:05,  2.81s/it]
#  95% 20/21 [00:51<00:02,  2.83s/it]
#
# {'eval_loss': '0.5601', 'eval_runtime': '55.61', 'eval_samples_per_second': '12.61', 'eval_steps_per_second': '0.396', 'epoch': '1.914'}
#  96% 400/418 [38:56<01:17,  4.29s/it]
# 100% 21/21 [00:53<00:00,  2.24s/it]
#                                    Unsloth: Restored added_tokens_decoder metadata in /content/drive/MyDrive/vlm-finetuning-project1/checkpoints/qwen3vl-2b/unified-sft64-v2-visionlora/checkpoint-400/tokenizer_config.json.
# {'loss': '0.5523', 'grad_norm': '0.4059', 'learning_rate': '1.693e-07', 'epoch': '1.919'}
# {'loss': '0.5632', 'grad_norm': '0.3735', 'learning_rate': '1.511e-07', 'epoch': '1.923'}
# {'loss': '0.5307', 'grad_norm': '0.4032', 'learning_rate': '1.338e-07', 'epoch': '1.928'}
# {'loss': '0.5282', 'grad_norm': '0.3752', 'learning_rate': '1.177e-07', 'epoch': '1.933'}
# {'loss': '0.5192', 'grad_norm': '0.4138', 'learning_rate': '1.025e-07', 'epoch': '1.938'}
# {'loss': '0.5209', 'grad_norm': '0.4046', 'learning_rate': '8.84e-08', 'epoch': '1.943'}
# {'loss': '0.526', 'grad_norm': '0.3738', 'learning_rate': '7.533e-08', 'epoch': '1.947'}
# {'loss': '0.5307', 'grad_norm': '0.4144', 'learning_rate': '6.331e-08', 'epoch': '1.952'}
# {'loss': '0.5675', 'grad_norm': '0.3953', 'learning_rate': '5.233e-08', 'epoch': '1.957'}
# {'loss': '0.4834', 'grad_norm': '0.3783', 'learning_rate': '4.239e-08', 'epoch': '1.962'}
# {'loss': '0.6154', 'grad_norm': '0.3982', 'learning_rate': '3.35e-08', 'epoch': '1.967'}
# {'loss': '0.5591', 'grad_norm': '0.4092', 'learning_rate': '2.565e-08', 'epoch': '1.971'}
# {'loss': '0.5315', 'grad_norm': '0.3972', 'learning_rate': '1.885e-08', 'epoch': '1.976'}
# {'loss': '0.5776', 'grad_norm': '0.4048', 'learning_rate': '1.309e-08', 'epoch': '1.981'}
# {'loss': '0.5573', 'grad_norm': '0.3877', 'learning_rate': '8.377e-09', 'epoch': '1.986'}
# {'loss': '0.4919', 'grad_norm': '0.409', 'learning_rate': '4.712e-09', 'epoch': '1.99'}
# {'loss': '0.5322', 'grad_norm': '0.3992', 'learning_rate': '2.094e-09', 'epoch': '1.995'}
# {'loss': '0.5387', 'grad_norm': '0.4369', 'learning_rate': '5.236e-10', 'epoch': '2'}
# 100% 418/418 [40:21<00:00,  4.54s/it]
#   0% 0/21 [00:00<?, ?it/s]
#  10% 2/21 [00:02<00:24,  1.27s/it]
#  14% 3/21 [00:04<00:31,  1.74s/it]
#  19% 4/21 [00:07<00:35,  2.11s/it]
#  24% 5/21 [00:09<00:34,  2.14s/it]
#  29% 6/21 [00:12<00:33,  2.23s/it]
#  33% 7/21 [00:15<00:34,  2.47s/it]
#  38% 8/21 [00:18<00:34,  2.69s/it]
#  43% 9/21 [00:20<00:31,  2.65s/it]
#  48% 10/21 [00:24<00:30,  2.77s/it]
#  52% 11/21 [00:26<00:27,  2.76s/it]
#  57% 12/21 [00:29<00:24,  2.77s/it]
#  62% 13/21 [00:32<00:22,  2.81s/it]
#  67% 14/21 [00:35<00:19,  2.81s/it]
#  71% 15/21 [00:38<00:16,  2.79s/it]
#  76% 16/21 [00:40<00:13,  2.79s/it]
#  81% 17/21 [00:43<00:11,  2.82s/it]
#  86% 18/21 [00:46<00:08,  2.82s/it]
#  90% 19/21 [00:49<00:05,  2.81s/it]
#  95% 20/21 [00:51<00:02,  2.78s/it]
#
# {'eval_loss': '0.56', 'eval_runtime': '55.86', 'eval_samples_per_second': '12.55', 'eval_steps_per_second': '0.394', 'epoch': '2'}
# 100% 418/418 [41:17<00:00,  4.54s/it]
# 100% 21/21 [00:53<00:00,  2.28s/it]
#                                    Unsloth: Restored added_tokens_decoder metadata in /content/drive/MyDrive/vlm-finetuning-project1/checkpoints/qwen3vl-2b/unified-sft64-v2-visionlora/checkpoint-418/tokenizer_config.json.
# {'train_runtime': '2482', 'train_samples_per_second': '5.39', 'train_steps_per_second': '0.168', 'train_loss': '0.6136', 'epoch': '2'}
# 100% 418/418 [41:22<00:00,  5.94s/it]
# Unsloth: Restored added_tokens_decoder metadata in /content/drive/MyDrive/vlm-finetuning-project1/checkpoints/qwen3vl-2b/unified-sft64-v2-visionlora/final/tokenizer_config.json.
# 2026-07-21 09:11:26 | INFO     | models.sft_trainer:run_sft_unified:359 - Saved final adapter snapshot to /content/drive/MyDrive/vlm-finetuning-project1/checkpoints/qwen3vl-2b/unified-sft64-v2-visionlora/final
# wandb: ⢿ updating run metadata (4.0s)
# wandb: ⣻ updating run metadata (4.0s)
# wandb: ⣽ updating run metadata (4.0s)
# wandb: ⣾ updating run metadata (4.0s)
# wandb: ⣷ Finishing up...
# wandb: ⣯ Finishing up...
# wandb: ⣟ Finishing up...
# wandb: ⡿ Finishing up...
# wandb: ⢿ Finishing up...
# wandb: ⣻ uploading output.log 48.7KB/48.7KB (0.3s)
# wandb: ⣻ uploading wandb-summary.json 612B/612B (0.3s)
# wandb: ⣻ uploading config.yaml 13.6KB/13.6KB (0.3s)
# wandb: ⣽ uploading output.log 48.7KB/48.7KB (0.3s)
# wandb: ⣽ uploading wandb-summary.json 612B/612B (0.3s)
# wandb: ⣽ uploading config.yaml 13.6KB/13.6KB (0.3s)
# wandb: ⣾ uploading output.log 48.7KB/48.7KB (0.3s)
# wandb: ⣾ uploading wandb-summary.json 612B/612B (0.3s)
# wandb: ⣾ uploading config.yaml 13.6KB/13.6KB (0.3s)
# wandb: ⣷ uploading output.log 48.7KB/48.7KB (0.3s)
# wandb: ⣷ uploading wandb-summary.json 612B/612B (0.3s)
# wandb: ⣷ uploading config.yaml 13.6KB/13.6KB (0.3s)
# wandb: ⣯ uploading output.log 48.7KB/48.7KB (0.3s)
# wandb: ⣯ uploading wandb-summary.json 612B/612B (0.3s)
# wandb: ⣯ uploading config.yaml 13.6KB/13.6KB (0.3s)
# wandb: ⣟ uploading output.log 48.7KB/48.7KB (0.8s)
# wandb: ⣟ uploading wandb-summary.json 612B/612B (0.8s)
# wandb: ⡿ uploading output.log 48.7KB/48.7KB (0.8s)
# wandb: ⡿ uploading wandb-summary.json 612B/612B (0.8s)
# wandb: ⢿ uploading output.log 48.7KB/48.7KB (0.8s)
# wandb: ⢿ uploading wandb-summary.json 612B/612B (0.8s)
# wandb: ⣻ uploading output.log 48.7KB/48.7KB (0.8s)
# wandb: ⣻ uploading wandb-summary.json 612B/612B (0.8s)
# wandb: ⣽ uploading output.log 48.7KB/48.7KB (0.8s)
# wandb: ⣽ uploading wandb-summary.json 612B/612B (0.8s)
# wandb: ⣾ uploading output.log 48.7KB/48.7KB (1.3s)
# wandb: ⣾ uploading wandb-summary.json 612B/612B (1.3s)
# wandb: ⣷ uploading output.log 48.7KB/48.7KB (1.3s)
# wandb: ⣷ uploading wandb-summary.json 612B/612B (1.3s)
# wandb: ⣯ uploading output.log 48.7KB/48.7KB (1.3s)
# wandb: ⣯ uploading wandb-summary.json 612B/612B (1.3s)
# wandb: ⣟ uploading output.log 48.7KB/48.7KB (1.3s)
# wandb: ⣟ uploading wandb-summary.json 612B/612B (1.3s)
# wandb: ⡿ uploading output.log 48.7KB/48.7KB (1.3s)
# wandb: ⡿ uploading wandb-summary.json 612B/612B (1.3s)
# wandb: ⢿ uploading history steps 426-427, summary, console lines 455-455 (0.4s)
# wandb: ⣻ uploading history steps 426-427, summary, console lines 455-455 (0.4s)
# wandb: ⣽ uploading history steps 426-427, summary, console lines 455-455 (0.4s)
# wandb: ⣾ uploading history steps 426-427, summary, console lines 455-455 (0.4s)
# wandb: ⣷ uploading history steps 426-427, summary, console lines 455-455 (0.4s)
# wandb: ⣯ uploading console lines 475-479 (0.3s)
# wandb: ⣟ uploading console lines 475-479 (0.3s)
# wandb:
# wandb: Run history:
# wandb:               eval/loss █▄▃▂▁▁▁▁▁
# wandb:            eval/runtime █▁▂▁▁▁▁▁▁
# wandb: eval/samples_per_second ▁█▇█▇███▇
# wandb:   eval/steps_per_second ▁█▇██████
# wandb:        gpu/allocated_gb ▁█
# wandb:    gpu/max_allocated_gb ▁█
# wandb:         gpu/reserved_gb ▁█
# wandb:             train/epoch ▁▂▂▂▂▂▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▅▅▅▅▅▅▅▆▆▆▆▇▇█████
# wandb:       train/global_step ▁▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▃▃▄▄▄▄▄▅▅▆▆▆▆▆▆▆▆▆▇▇▇▇▇█
# wandb:         train/grad_norm █▇▄▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:                      +2 ...
# wandb:
# wandb: Run summary:
# wandb:               eval/loss 0.56003
# wandb:            eval/runtime 55.863
# wandb: eval/samples_per_second 12.549
# wandb:   eval/steps_per_second 0.394
# wandb:        gpu/allocated_gb 3.22751
# wandb:    gpu/max_allocated_gb 8.63006
# wandb:         gpu/reserved_gb 8.82062
# wandb:              total_flos 1.3607400274919424e+17
# wandb:             train/epoch 2
# wandb:       train/global_step 418
# wandb:                      +7 ...
# wandb:
# wandb: 🚀 View run qwen3vl-2b-unified-sft64-v2-visionlora at: https://wandb.ai/nabeel-shan-research-national-university-of-sciences-and/vlm-safety-project1/runs/ajsjbuoq
# wandb: ⭐️ View project at: https://wandb.ai/nabeel-shan-research-national-university-of-sciences-and/vlm-safety-project1
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20260721_082955-ajsjbuoq/logs
# 2026-07-21 09:11:29 | INFO     | __main__:main:94 - SFT run complete. Best/final checkpoint at /content/drive/MyDrive/vlm-finetuning-project1/checkpoints/qwen3vl-2b/unified-sft64-v2-visionlora/best
